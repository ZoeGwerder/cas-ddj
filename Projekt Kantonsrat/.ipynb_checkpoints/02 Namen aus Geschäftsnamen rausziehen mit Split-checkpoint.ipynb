# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup
from datetime import datetime
import numpy as np
import requests, zipfile, io #zum abspeichern von PDFs
from tqdm import tqdm
import PyPDF2
import re
from os import listdir
from os.path import isfile, join

# %% [markdown]
# ## URL von allen Hauptseiten holen

# %%
#alle urls und infos der Hauptseiten holen.
url = "https://kr-geschaefte.zug.ch/gast/geschaefte?commit=Filtern&geschaeft_filter%5Babgeschlossen_bis%5D=&geschaeft_filter%5Babgeschlossen_von%5D=&geschaeft_filter%5Barten_refs%5D%5B%5D=&geschaeft_filter%5Beingereicht_bis%5D=&geschaeft_filter%5Beingereicht_von%5D=&geschaeft_filter%5Bfrist_bis%5D=&geschaeft_filter%5Bhistorische_staende_refs%5D%5B%5D=&geschaeft_filter%5Bkommissionen_refs%5D%5B%5D=&geschaeft_filter%5Bstaende_refs%5D%5B%5D=&geschaeft_filter%5Bstatus_ids%5D%5B%5D=haengig&geschaeft_filter%5Bstatus_ids%5D%5B%5D=abgeschlossen&geschaeft_filter%5Bstatus_ids%5D%5B%5D=&geschaeft_filter%5Btitel%5D=&geschaeft_filter%5Bzustaendig_refs%5D%5B%5D=&page="

alle_seiten = []
for seite in range(1,41):
    r=requests.get(url+str(seite))
    soup = BeautifulSoup(r.text,"html.parser")
    
    tr_list=soup.find_all("tr")[2:] #erst ab der Position 2 sind die Daten relevant.
    
    for element in tr_list:
        td_list = element.find_all("td")
        vorlag_nr=td_list[0].text
        href = td_list[0].find("a")["href"]
        text = td_list[1].text
        stand = td_list[2].text
        zustaendig = td_list[3].text
        geschaeft_art = td_list[4].text
        status = td_list[5].text
        
        mini_dict = {"VorlageNR":vorlag_nr,"url":href,"Geschäft":text, "Stand":stand, "Zuständigkeit":zustaendig, "Art des Geschäfts": geschaeft_art, "Status":status}

        alle_seiten.append(mini_dict)

# %%
pd.DataFrame(alle_seiten)

# %%
df_vs=pd.read_csv("KRFrames/df_v_Hauptseiten")

# %%
df_vs
# Out:
#       Unnamed: 0  index  VorlageNR                    url  \
# 0              0      0       3020  /gast/geschaefte/2008
# 1              1      1       3019  /gast/geschaefte/2007
# 2              2      2       3018  /gast/geschaefte/2006
# 3              3      3       3017  /gast/geschaefte/2005
# 4              4      6       3014  /gast/geschaefte/2002
# ...          ...    ...        ...                    ...
# 1215        1215   1946        762  /gast/geschaefte/1331
# 1216        1216   1952        666  /gast/geschaefte/1325
# 1217        1217   1968        304  /gast/geschaefte/1309
# 1218        1218   1969        282  /gast/geschaefte/1712
# 1219        1219   1972         81  /gast/geschaefte/1334
#
#                                                Geschäft  \
# 0     Postulat von Luzian Franzini und Esther Haas b...
# 1     Motion von Luzian Franzini, Rita Hofer, Tabea ...
# 2     Interpellation von Fabio Iten, Laura Dittli un...
# 3     Postulat von Tabea Zimmermann Gibson, Stéphani...
# 4     Interpellation der SVP-Fraktion betreffend mob...
# ...                                                 ...
# 1215  Motion der erweiterten Justizprüfungskommissio...
# 1216  Motion der Kommission Teilrevision Personalges...
# 1217  Motion von Manuela Weichelt betreffend HIV-Prä...
# 1218  Motion von Christoph Hohler betreffend Radstre...
# 1219  Motion der vorberatenden Kommission betreffend...
#
#                              Stand              Zuständigkeit  \
# 0     Überweisung an Regierungsrat       Sicherheitsdirektion
# 1     Überweisung an Regierungsrat       Direktion des Innern
# 2     Überweisung an Regierungsrat  Volkswirtschaftsdirektion
# 3     Überweisung an Regierungsrat       Direktion des Innern
# 4                    Kenntnisnahme       Sicherheitsdirektion
# ...                            ...                        ...
# 1215                Datenmigration                        NaN
# 1216                Datenmigration                        NaN
# 1217                Datenmigration                        NaN
# 1218               Frist erstreckt               Baudirektion
# 1219                Datenmigration                        NaN
#
#      Art des Geschäfts         Status
# 0             Postulat         hängig
# 1               Motion         hängig
# 2       Interpellation         hängig
# 3             Postulat         hängig
# 4       Interpellation         hängig
# ...                ...            ...
# 1215            Motion  abgeschlossen
# 1216            Motion  abgeschlossen
# 1217            Motion  abgeschlossen
# 1218            Motion         hängig
# 1219            Motion  abgeschlossen
#
# [1220 rows x 9 columns]

# %% [markdown]
# # hier ein Test von Barnaby, wie man die Namen alleine mit "Split" separieren kann
#
# - Vielleicht zuerst noch mit Pandas nur die Vorstösse raussuchen. Ist ja das, was mich interessiert.
# - Rausfinden, wie ich die Namen nun rausziehe und in ein aufklappbares Dataframe stelle

# %%
def splitting(elem):
    elem = elem.split('betreffend')[0].strip()
    if 'von' in elem:
        elem = elem.split('von')[1].strip()
        elem = elem.replace(' und', ',')
    elif 'der' in elem:
        elem = elem.split('der')[1].strip()    
    return elem
df_vs["Geschäft"]=df_vs['Geschäft'].apply(splitting) #.apply ist um eine Funktion auf eine ganze Reihe Pandas einzusetze

# %% [markdown]
# # Nun rausfinden, wie ich ein DataFrame machen kann, das man aufklappt

# %%
df_vs.head()
# Out:
#    Unnamed: 0  index  VorlageNR                    url  \
# 0           0      0       3020  /gast/geschaefte/2008
# 1           1      1       3019  /gast/geschaefte/2007
# 2           2      2       3018  /gast/geschaefte/2006
# 3           3      3       3017  /gast/geschaefte/2005
# 4           4      6       3014  /gast/geschaefte/2002
#
#                                             Geschäft  \
# 0                       Luzian Franzini, Esther Haas
# 1  Luzian Franzini, Rita Hofer, Tabea Zimmermann ...
# 2               Fabio Iten, Laura Dittli, Anna Bieri
# 3  Tabea Zimmermann Gibson, Stéphanie Vuichard, E...
# 4                                       SVP-Fraktion
#
#                           Stand              Zuständigkeit Art des Geschäfts  \
# 0  Überweisung an Regierungsrat       Sicherheitsdirektion          Postulat
# 1  Überweisung an Regierungsrat       Direktion des Innern            Motion
# 2  Überweisung an Regierungsrat  Volkswirtschaftsdirektion    Interpellation
# 3  Überweisung an Regierungsrat       Direktion des Innern          Postulat
# 4                 Kenntnisnahme       Sicherheitsdirektion    Interpellation
#
#    Status
# 0  hängig
# 1  hängig
# 2  hängig
# 3  hängig
# 4  hängig

# %%
#das funktionerit also nicht
def splitkomma(elem):
    elem=elem.split(", ")
    return elem

# %%
df_vs["Geschäft"]=df_vs["Geschäft"].apply(splitkomma)

# %%
# Hier die Lösung, wie ich für jeden Namen ein einzelnes Geschäft erhalte

# %%
df_ex=df_vs.explode('Geschäft').reset_index(drop=True)

# %%
df_ex.rename(columns={'Geschäft':'Namenganz'}, inplace=True)

# %%
df_ex.to_csv("KRFrames/df_ex")

# %%
df_ex=pd.read_csv("KRFrames/df_ex")

# %%
# hier schaue ich, wie gross das Dataframe ohne die Kommissionen und so ist.
df_ex_cl=df_ex[df_ex["Namenganz"].str.contains("Kommission|kommission")==False]

# %%
df_ex_cl=df_ex_cl[["VorlageNR", "Namenganz", ]]

# %%
# ICH bereinige von Hand im Excel
df_ex_cl.to_excel("KRFrames/df_ex_cl.xlsx")

# %%
df_ex_cl[df_ex_cl["Namenganz"].str.contains("zur")]
#oook, die Alternativen wurden unteschiedliche benamselt. Das muss ich genauer anschauen.
# Auch andere Parteien werden zum Teil doppelt genannt.
# Out:
#       VorlageNR                                          Namenganz
# 779        2362  Manfred Wenger zur Beantwortung der Kleinen An...
# 1273       1794                  zur Förderung der Hausarztmedizin
# 1286       1781                       FDP-Fraktion zur Abschaffung
# 1515       1542  Alois Gössi zur Ergänzung des Kantonsratsbesch...
# 1663       1361  Kathrin Kündig zur Schaffung einer Höheren Fac...
# 1703       1315          Jean-Pierre Prodolliet zur Interpellation

# %% [markdown]
# # Bereinigen der Parteinamen
# Diese werden in mindestens drei unterschiedlichen Arten genannt
#
# ### Ich habe mich fürs Bereinigen im Excel entschieden, da Daten noch übersichtlich sind

# %%
# Hier nun das im Excel bereinigte Sheet
df_ex_ber=pd.read_excel("KRFrames/df_ex_cl_geputzt.xlsx")

# %% [markdown]
# ### Problem erkannt:
# offenbar werden gekoppelte Namen in den Geschäften nur mit den ersten aufgeführt.

# %%
df_ex_ber.set_index("Unnamed: 0")
# Out:
#             VorlageNR                Namenganz
# Unnamed: 0
# 0                3020          Luzian Franzini
# 1                3020              Esther Haas
# 2                3019          Luzian Franzini
# 3                3019               Rita Hofer
# 4                3019  Tabea Zimmermann Gibson
# ...               ...                      ...
# 1937              836         Käty Hofer Buser
# 1940              810             Marcel Meyer
# 1941              801              Hans Abicht
# 1944              304         Manuela Weichelt
# 1945              282         Christoph Hohler
#
# [1915 rows x 2 columns]

# %%
df_ex_ber.shape
# Out:
# (1915, 3)

# %%
# Nun das Frame mit den Namen einlesen
df_np=pd.read_excel('KRFrames/Alle_Namen_mit_Allianz_und_ohne_ergänzt.xlsx')

# %%
#von der Bearbeitung hat es nun noch einen anderen Index. stört uns nicht - Wir entfernen "unnamed:0"
del df_np["Unnamed: 0"]

# %%
df_np.shape #voila
# Out:
# (402, 3)

# %%
#Nun die beiden zusammenfügen - an den Namen
df_alles=pd.merge(df_np, df_ex_ber, how="right",on= "Namenganz", )

# %%
df_alles=df_alles.sort_values("Unnamed: 0")

# %%
df_alles
# Out:
#                     Namenganz    P  Unnamed: 0.1  Unnamed: 0  VorlageNR
# 1814          Luzian Franzini  ALG           NaN           0       3020
# 1012              Esther Haas  ALG           NaN           1       3020
# 1815          Luzian Franzini  ALG           NaN           2       3019
# 1225               Rita Hofer  ALG           NaN           3       3019
# 1317  Tabea Zimmermann Gibson  ALG           NaN           4       3019
# ...                       ...  ...           ...         ...        ...
# 110          Käty Hofer Buser   SP           NaN        1937        836
# 14               Marcel Meyer  CVP           NaN        1940        810
# 23                Hans Abicht  FDP           NaN        1941        801
# 25           Manuela Weichelt  ALG           NaN        1944        304
# 24           Christoph Hohler   SP           NaN        1945        282
#
# [1944 rows x 5 columns]

# %%
df_alles.sort_values("P").tail(60)
# Out:
#                                               Namenganz    P  Unnamed: 0.1  \
# 1884                                  Karin Andenmatten  NaN           NaN
# 1880                                             Roland  NaN           NaN
# 1885                                  Karin Andenmatten  NaN           NaN
# 1886                                  Karin Andenmatten  NaN           NaN
# 1887                                  Karin Andenmatten  NaN           NaN
# 1892                                     Erwina Winiger  NaN           NaN
# 1898  Generalsekretär den aktuellen Stand sämtlicher...  NaN           NaN
# 1899  bei Ausfall des Direktionsvorstehers dem stv. ...  NaN           NaN
# 1900                             Alternativen Fraktion   NaN           NaN
# 1901                             Alternativen Fraktion   NaN           NaN
# 1902                             Alternativen Fraktion   NaN           NaN
# 1903                                       CVP Fraktion  NaN           NaN
# 1904                                    Hubert Schuler   NaN           NaN
# 1905                  zur Förderung der Hausarztmedizin  NaN           NaN
# 1906                                      FDP-Fraktion   NaN           NaN
# 1907                                      FDP-Fraktion   NaN           NaN
# 1893                                     Erwina Winiger  NaN           NaN
# 1908                                   Beni Langenegger  NaN           NaN
# 1910                                Karin Julia Stadlin  NaN           NaN
# 1888                                  Karin Andenmatten  NaN           NaN
# 1889                                  Karin Andenmatten  NaN           NaN
# 1911                                    Andreas Huwyler  NaN           NaN
# 1916                                          digitalen  NaN           NaN
# 1917                             audio-visuellen Medien  NaN           NaN
# 1918                               einem Verkaufsverbot  NaN           NaN
# 1919                                 Personalcomputern"  NaN           NaN
# 1894                                     Erwina Winiger  NaN           NaN
# 1920                                    Christina Huber  NaN           NaN
# 1890                                  Karin Andenmatten  NaN           NaN
# 1921                                    Christina Huber  NaN           NaN
# 1895                                     Erwina Winiger  NaN           NaN
# 1896                                     Erwina Winiger  NaN           NaN
# 1922                                    Christina Huber  NaN           NaN
# 1923                                    Christina Huber  NaN           NaN
# 1912                                    Andreas Huwyler  NaN           NaN
# 1924                                    Christina Huber  NaN           NaN
# 1925                                     Chrstina Huber  NaN           NaN
# 1897                                     Erwina Winiger  NaN           NaN
# 1913                                    Andreas Huwyler  NaN           NaN
# 1926                          CVP-Fraktion SVP-Fraktion  NaN           NaN
# 1927                             Baarer Kantonsrätinnen  NaN           NaN
# 1928                                       Kantonsräten  NaN           NaN
# 1930                                     Rolf Schweiger  NaN           NaN
# 1931                                       Othmar Birri  NaN           NaN
# 1914                                    Andreas Huwyler  NaN           NaN
# 1915                                    Andreas Huwyler  NaN           NaN
# 1909                                   Beni Langenegger  NaN           NaN
# 1934                                    Kathrin Kündig   NaN           NaN
# 1935                                       SP-Fraktion   NaN           NaN
# 1932                                       Othmar Birri  NaN           NaN
# 1936                            Jean-Pierre Prodolliet   NaN           NaN
# 1937                                    Stefan Schleiss  NaN           NaN
# 1938                             Chamer Kantonsrätinnen  NaN           NaN
# 1929                                       Kantonsräten  NaN           NaN
# 1939                                        Andrea Erni  NaN           NaN
# 1933                                       Othmar Birri  NaN           NaN
# 1940                                               CSV,  NaN           NaN
# 1941  Beat Villiger für ein Überdachungsprojekt Auto...  NaN           NaN
# 1942  Rosemarie Fähndrich Burger für einen vernünftigen  NaN           NaN
# 1943  gerechten Finanzausgleich unter den katholisch...  NaN           NaN
#
#       Unnamed: 0  VorlageNR
# 1884         974       2133
# 1880        1000       2110
# 1885        1017       2085
# 1886        1020       2084
# 1887        1099       2012
# 1892        1111       1997
# 1898        1169       1923
# 1899        1170       1923
# 1900        1198       1882
# 1901        1204       1879
# 1902        1214       1865
# 1903        1227       1843
# 1904        1272       1794
# 1905        1273       1794
# 1906        1286       1781
# 1907        1287       1780
# 1893        1304       1763
# 1908        1306       1761
# 1910        1311       1758
# 1888        1318       1752
# 1889        1324       1743
# 1911        1326       1743
# 1916        1337       1740
# 1917        1338       1740
# 1918        1339       1740
# 1919        1400       1679
# 1894        1414       1657
# 1920        1415       1656
# 1890        1416       1655
# 1921        1438       1634
# 1895        1440       1634
# 1896        1445       1632
# 1922        1450       1621
# 1923        1470       1587
# 1912        1471       1586
# 1924        1488       1579
# 1925        1491       1577
# 1897        1543       1515
# 1913        1557       1502
# 1926        1579       1474
# 1927        1606       1441
# 1928        1607       1441
# 1930        1611       1426
# 1931        1616       1423
# 1914        1634       1389
# 1915        1640       1381
# 1909        1656       1363
# 1934        1663       1361
# 1935        1676       1347
# 1932        1685       1330
# 1936        1703       1315
# 1937        1710       1308
# 1938        1751       1259
# 1929        1752       1259
# 1939        1764       1229
# 1933        1798       1186
# 1940        1893       1042
# 1941        1923        958
# 1942        1930        916
# 1943        1931        916

# %%
df_alles.set_index("Unnamed: 0")
# Out:
#                           Namenganz    P  Unnamed: 0.1  VorlageNR
# Unnamed: 0
# 0                   Luzian Franzini  ALG           NaN       3020
# 1                       Esther Haas  ALG           NaN       3020
# 2                   Luzian Franzini  ALG           NaN       3019
# 3                        Rita Hofer  ALG           NaN       3019
# 4           Tabea Zimmermann Gibson  ALG           NaN       3019
# ...                             ...  ...           ...        ...
# 1937               Käty Hofer Buser   SP           NaN        836
# 1940                   Marcel Meyer  CVP           NaN        810
# 1941                    Hans Abicht  FDP           NaN        801
# 1944               Manuela Weichelt  ALG           NaN        304
# 1945               Christoph Hohler   SP           NaN        282
#
# [1944 rows x 4 columns]

# %%
df_alles.dtypes
# Out:
# Namenganz        object
# P                object
# Unnamed: 0.1    float64
# Unnamed: 0        int64
# VorlageNR         int64
# dtype: object

# %%
# hier schaue ich, wie gross das Dataframe ohne die Kommissionen und so ist.

# %%
# nun das df_alles noch abspeichern für den Endcode
df_alles.to_csv("KRFrames/Frame_mit_Namen_und_Parteien")

# %% [markdown]
# # IRRWEGE

# %%
nameliste=df_vs["Geschäft"].tolist()

# %%
nameliste

# %% [markdown]
# nameliste[1] range(0:1219)

# %%
len(nameliste)

# %%
lestlist=[]
lestlist.append("suppe")
len(lestlist)

# %%
namenliste_n=[]
counter = 0
zaehler = 0

for alleeintraege in df_vs["Geschäft"]: #hier gehe ich jede Liste im Dataframe an.
    print(alleeintraege)
    name = alleeintraege[zaehler] #ich will sie auslesen und die Namen einzeln.

    if zaehler < len(alleeintraege)-1: #da die Listen unterschiedlich lang sind, versuche ich hier dies zu berücksichtigen
        zaehler=zaehler+1 #es scheint leider nicht zu funktionieren. 
    elif zaehler == (alleeintraege)-1: 
        continue
   
          
    
    minidictnamen={"Name":name}
    namenliste_n.append(minidictnamen)

# %%
pd.DataFrame(namenliste_n)

# %%
return tuple(namenliste_n)

# %%
#Ich versuche es mal schriftlich bevor ich den Loop schreibe:
liste=[]
namenliste={"sophie", "anna","julia"}
minidicttest={"ART": "Motion", "NUMMER": 23455, "NAMEN":namenliste}
liste.append(minidicttest)

# %%
df_test=pd.DataFrame(liste)

# %%
df_test

# %%
for key, value in minidict_g.items():
        if value == '':
            minidict_g[key] = 'NaN'  #hier schaue ich noch, dass ich die Leeren Zeilen mit NAN ersetzten kann.
        else:
            minidict_g[key] = value
