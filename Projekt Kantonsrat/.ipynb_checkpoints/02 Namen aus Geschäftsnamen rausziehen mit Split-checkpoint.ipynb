# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup
from datetime import datetime
import numpy as np
import requests, zipfile, io #zum abspeichern von PDFs
from tqdm import tqdm
import PyPDF2
import re
from os import listdir
from os.path import isfile, join

# %% [markdown]
# ## URL von allen Hauptseiten holen

# %%
#alle urls und infos der Hauptseiten holen.
url = "https://kr-geschaefte.zug.ch/gast/geschaefte?commit=Filtern&geschaeft_filter%5Babgeschlossen_bis%5D=&geschaeft_filter%5Babgeschlossen_von%5D=&geschaeft_filter%5Barten_refs%5D%5B%5D=&geschaeft_filter%5Beingereicht_bis%5D=&geschaeft_filter%5Beingereicht_von%5D=&geschaeft_filter%5Bfrist_bis%5D=&geschaeft_filter%5Bhistorische_staende_refs%5D%5B%5D=&geschaeft_filter%5Bkommissionen_refs%5D%5B%5D=&geschaeft_filter%5Bstaende_refs%5D%5B%5D=&geschaeft_filter%5Bstatus_ids%5D%5B%5D=haengig&geschaeft_filter%5Bstatus_ids%5D%5B%5D=abgeschlossen&geschaeft_filter%5Bstatus_ids%5D%5B%5D=&geschaeft_filter%5Btitel%5D=&geschaeft_filter%5Bzustaendig_refs%5D%5B%5D=&page="

alle_seiten = []
for seite in range(1,41):
    r=requests.get(url+str(seite))
    soup = BeautifulSoup(r.text,"html.parser")
    
    tr_list=soup.find_all("tr")[2:] #erst ab der Position 2 sind die Daten relevant.
    
    for element in tr_list:
        td_list = element.find_all("td")
        vorlag_nr=td_list[0].text
        href = td_list[0].find("a")["href"]
        text = td_list[1].text
        stand = td_list[2].text
        zustaendig = td_list[3].text
        geschaeft_art = td_list[4].text
        status = td_list[5].text
        
        mini_dict = {"VorlageNR":vorlag_nr,"url":href,"Geschäft":text, "Stand":stand, "Zuständigkeit":zustaendig, "Art des Geschäfts": geschaeft_art, "Status":status}

        alle_seiten.append(mini_dict)

# %%
pd.DataFrame(alle_seiten)

# %%
df_vs=pd.read_csv("KRFrames/df_v_Hauptseiten")

# %%
df_vs
# Out:
#       Unnamed: 0  index  VorlageNR                    url  \
# 0              0      0       3020  /gast/geschaefte/2008
# 1              1      1       3019  /gast/geschaefte/2007
# 2              2      2       3018  /gast/geschaefte/2006
# 3              3      3       3017  /gast/geschaefte/2005
# 4              4      6       3014  /gast/geschaefte/2002
# ...          ...    ...        ...                    ...
# 1215        1215   1946        762  /gast/geschaefte/1331
# 1216        1216   1952        666  /gast/geschaefte/1325
# 1217        1217   1968        304  /gast/geschaefte/1309
# 1218        1218   1969        282  /gast/geschaefte/1712
# 1219        1219   1972         81  /gast/geschaefte/1334
#
#                                                Geschäft  \
# 0     Postulat von Luzian Franzini und Esther Haas b...
# 1     Motion von Luzian Franzini, Rita Hofer, Tabea ...
# 2     Interpellation von Fabio Iten, Laura Dittli un...
# 3     Postulat von Tabea Zimmermann Gibson, Stéphani...
# 4     Interpellation der SVP-Fraktion betreffend mob...
# ...                                                 ...
# 1215  Motion der erweiterten Justizprüfungskommissio...
# 1216  Motion der Kommission Teilrevision Personalges...
# 1217  Motion von Manuela Weichelt betreffend HIV-Prä...
# 1218  Motion von Christoph Hohler betreffend Radstre...
# 1219  Motion der vorberatenden Kommission betreffend...
#
#                              Stand              Zuständigkeit  \
# 0     Überweisung an Regierungsrat       Sicherheitsdirektion
# 1     Überweisung an Regierungsrat       Direktion des Innern
# 2     Überweisung an Regierungsrat  Volkswirtschaftsdirektion
# 3     Überweisung an Regierungsrat       Direktion des Innern
# 4                    Kenntnisnahme       Sicherheitsdirektion
# ...                            ...                        ...
# 1215                Datenmigration                        NaN
# 1216                Datenmigration                        NaN
# 1217                Datenmigration                        NaN
# 1218               Frist erstreckt               Baudirektion
# 1219                Datenmigration                        NaN
#
#      Art des Geschäfts         Status
# 0             Postulat         hängig
# 1               Motion         hängig
# 2       Interpellation         hängig
# 3             Postulat         hängig
# 4       Interpellation         hängig
# ...                ...            ...
# 1215            Motion  abgeschlossen
# 1216            Motion  abgeschlossen
# 1217            Motion  abgeschlossen
# 1218            Motion         hängig
# 1219            Motion  abgeschlossen
#
# [1220 rows x 9 columns]

# %% [markdown]
# # hier ein Test von Barnaby, wie man die Namen alleine mit "Split" separieren kann
#
# - Vielleicht zuerst noch mit Pandas nur die Vorstösse raussuchen. Ist ja das, was mich interessiert.
# - Rausfinden, wie ich die Namen nun rausziehe und in ein aufklappbares Dataframe stelle

# %%
def splitting(elem):
    elem = elem.split('betreffend')[0].strip()
    if 'von' in elem:
        elem = elem.split('von')[1].strip()
        elem = elem.replace(' und', ',')
    elif 'der' in elem:
        elem = elem.split('der')[1].strip()    
    return elem
df_vs["Geschäft"]=df_vs['Geschäft'].apply(splitting) #.apply ist um eine Funktion auf eine ganze Reihe Pandas einzusetze

# %% [markdown]
# # Nun rausfinden, wie ich ein DataFrame machen kann, das man aufklappt

# %%
df_vs.tail(10)
# Out:
#       Unnamed: 0  index  VorlageNR                    url  \
# 1210        1210   1939        836  /gast/geschaefte/1339
# 1211        1211   1941        823  /gast/geschaefte/1337
# 1212        1212   1942        822  /gast/geschaefte/1336
# 1213        1213   1943        810  /gast/geschaefte/1335
# 1214        1214   1944        801  /gast/geschaefte/1333
# 1215        1215   1946        762  /gast/geschaefte/1331
# 1216        1216   1952        666  /gast/geschaefte/1325
# 1217        1217   1968        304  /gast/geschaefte/1309
# 1218        1218   1969        282  /gast/geschaefte/1712
# 1219        1219   1972         81  /gast/geschaefte/1334
#
#                                     Geschäft            Stand Zuständigkeit  \
# 1210                        Käty Hofer Buser   Datenmigration           NaN
# 1211             Kommission Parlamentsreform   Datenmigration           NaN
# 1212             Kommission Parlamentsreform   Datenmigration           NaN
# 1213                            Marcel Meyer   Datenmigration           NaN
# 1214                             Hans Abicht   Datenmigration           NaN
# 1215    erweiterten Justizprüfungskommission   Datenmigration           NaN
# 1216  Kommission Teilrevision Personalgesetz   Datenmigration           NaN
# 1217                        Manuela Weichelt   Datenmigration           NaN
# 1218                        Christoph Hohler  Frist erstreckt  Baudirektion
# 1219                vorberatenden Kommission   Datenmigration           NaN
#
#      Art des Geschäfts         Status
# 1210    Interpellation  abgeschlossen
# 1211            Motion  abgeschlossen
# 1212            Motion  abgeschlossen
# 1213            Motion  abgeschlossen
# 1214            Motion  abgeschlossen
# 1215            Motion  abgeschlossen
# 1216            Motion  abgeschlossen
# 1217            Motion  abgeschlossen
# 1218            Motion         hängig
# 1219            Motion  abgeschlossen

# %%
#das funktionerit also nicht
def splitkomma(elem):
    elem=elem.split(", ")
    return elem

# %%
df_vs["Geschäft"]=df_vs["Geschäft"].apply(splitkomma)

# %%
# Hier die Lösung, wie ich für jeden Namen ein einzelnes Geschäft erhalte

# %%
df_ex=df_vs.explode('Geschäft').reset_index(drop=True)

# %%
df_ex.rename(columns={'Geschäft':'Namenganz'}, inplace=True)

# %%
df_ex
# Out:
#       Unnamed: 0  index  VorlageNR                    url  \
# 0              0      0       3020  /gast/geschaefte/2008
# 1              0      0       3020  /gast/geschaefte/2008
# 2              1      1       3019  /gast/geschaefte/2007
# 3              1      1       3019  /gast/geschaefte/2007
# 4              1      1       3019  /gast/geschaefte/2007
# ...          ...    ...        ...                    ...
# 1942        1215   1946        762  /gast/geschaefte/1331
# 1943        1216   1952        666  /gast/geschaefte/1325
# 1944        1217   1968        304  /gast/geschaefte/1309
# 1945        1218   1969        282  /gast/geschaefte/1712
# 1946        1219   1972         81  /gast/geschaefte/1334
#
#                                    Namenganz                         Stand  \
# 0                            Luzian Franzini  Überweisung an Regierungsrat
# 1                                Esther Haas  Überweisung an Regierungsrat
# 2                            Luzian Franzini  Überweisung an Regierungsrat
# 3                                 Rita Hofer  Überweisung an Regierungsrat
# 4                    Tabea Zimmermann Gibson  Überweisung an Regierungsrat
# ...                                      ...                           ...
# 1942    erweiterten Justizprüfungskommission                Datenmigration
# 1943  Kommission Teilrevision Personalgesetz                Datenmigration
# 1944                        Manuela Weichelt                Datenmigration
# 1945                        Christoph Hohler               Frist erstreckt
# 1946                vorberatenden Kommission                Datenmigration
#
#              Zuständigkeit Art des Geschäfts         Status
# 0     Sicherheitsdirektion          Postulat         hängig
# 1     Sicherheitsdirektion          Postulat         hängig
# 2     Direktion des Innern            Motion         hängig
# 3     Direktion des Innern            Motion         hängig
# 4     Direktion des Innern            Motion         hängig
# ...                    ...               ...            ...
# 1942                   NaN            Motion  abgeschlossen
# 1943                   NaN            Motion  abgeschlossen
# 1944                   NaN            Motion  abgeschlossen
# 1945          Baudirektion            Motion         hängig
# 1946                   NaN            Motion  abgeschlossen
#
# [1947 rows x 9 columns]

# %%
# Nun das Frame mit den Namen einlesen
df_np=pd.read_excel('Namen_und_parteien.xlsx')

# %%
#von der Bearbeitung hat es nun noch einen anderen Index. stört uns nicht - Wir entfernen "unnamed:0"
del df_np["Unnamed: 0"]

# %%
df_np #voila
# Out:
#                  Namenganz    P
# 0         Judith Wild-Haas  FDP
# 1        Madeleine Landolt  SGA
# 2            Peter Bossard  FDP
# 3      Susi Frei-Schläpfer  FDP
# 4          Alois Henggeler  CVP
# ..                     ...  ...
# 340           SVP-Fraktion  SVP
# 341           FDP-Fraktion  FDP
# 342           CVP-Fraktion  CVP
# 343            SP-Fraktion   SP
# 344  Alternativen Fraktion  ALG
#
# [345 rows x 2 columns]

# %%
#Nun die beiden zusammenfügen - an den Namen
df_alles=pd.merge(df_ex, df_np, how="inner",on= "Namenganz", )

# %%
df_alles.head(40)
# Out:
#     Unnamed: 0  index  VorlageNR                    url  \
# 0            0      0       3020  /gast/geschaefte/2008
# 1            3      3       3017  /gast/geschaefte/2005
# 2           33     47       2973  /gast/geschaefte/1961
# 3           55     86       2934  /gast/geschaefte/1922
# 4           59     90       2930  /gast/geschaefte/1918
# 5           60     91       2929  /gast/geschaefte/1917
# 6           99    162       2856  /gast/geschaefte/1846
# 7          192    288       2729  /gast/geschaefte/1717
# 8          193    289       2728  /gast/geschaefte/1716
# 9          198    294       2723  /gast/geschaefte/1711
# 10         290    432       2583  /gast/geschaefte/1569
# 11         303    453       2561  /gast/geschaefte/1548
# 12         322    480       2534  /gast/geschaefte/1521
# 13         405    595       2416  /gast/geschaefte/1400
# 14         464    668       2333   /gast/geschaefte/585
# 15         468    677       2324   /gast/geschaefte/574
# 16           1      1       3019  /gast/geschaefte/2007
# 17           7     11       3009  /gast/geschaefte/1997
# 18          23     36       2984  /gast/geschaefte/1972
# 19          55     86       2934  /gast/geschaefte/1922
# 20          60     91       2929  /gast/geschaefte/1917
# 21          62     93       2927  /gast/geschaefte/1915
# 22          71    108       2912  /gast/geschaefte/1900
# 23          85    141       2879  /gast/geschaefte/1867
# 24          86    142       2878  /gast/geschaefte/1866
# 25          98    161       2857  /gast/geschaefte/1847
# 26         303    453       2561  /gast/geschaefte/1548
# 27           1      1       3019  /gast/geschaefte/2007
# 28           3      3       3017  /gast/geschaefte/2005
# 29          34     48       2972  /gast/geschaefte/1960
# 30          45     70       2950  /gast/geschaefte/1937
# 31          55     86       2934  /gast/geschaefte/1922
# 32          60     91       2929  /gast/geschaefte/1917
# 33           1      1       3019  /gast/geschaefte/2007
# 34           6     10       3010  /gast/geschaefte/1998
# 35          16     23       2997  /gast/geschaefte/1985
# 36          26     40       2980  /gast/geschaefte/1968
# 37          34     48       2972  /gast/geschaefte/1960
# 38          45     70       2950  /gast/geschaefte/1937
# 39          51     78       2942  /gast/geschaefte/1930
#
#                   Namenganz                         Stand  \
# 0               Esther Haas  Überweisung an Regierungsrat
# 1               Esther Haas  Überweisung an Regierungsrat
# 2               Esther Haas  Überweisung an Regierungsrat
# 3               Esther Haas      Nicht-Erheblicherklärung
# 4               Esther Haas             Erledigterklärung
# 5               Esther Haas              Nichtüberweisung
# 6               Esther Haas                 Kenntnisnahme
# 7               Esther Haas    Antwort des Regierungsrats
# 8               Esther Haas      Nicht-Erheblicherklärung
# 9               Esther Haas                 Kenntnisnahme
# 10              Esther Haas             Erledigterklärung
# 11              Esther Haas                 Kenntnisnahme
# 12              Esther Haas    Antwort des Regierungsrats
# 13              Esther Haas    Antwort des Regierungsrats
# 14              Esther Haas                 Kenntnisnahme
# 15              Esther Haas                 Kenntnisnahme
# 16               Rita Hofer  Überweisung an Regierungsrat
# 17               Rita Hofer  Überweisung an Regierungsrat
# 18               Rita Hofer    Antwort des Regierungsrats
# 19               Rita Hofer      Nicht-Erheblicherklärung
# 20               Rita Hofer              Nichtüberweisung
# 21               Rita Hofer                 Kenntnisnahme
# 22               Rita Hofer    Antwort des Regierungsrats
# 23               Rita Hofer            Erheblicherklärung
# 24               Rita Hofer    Antwort des Regierungsrats
# 25               Rita Hofer                 Kenntnisnahme
# 26               Rita Hofer                 Kenntnisnahme
# 27  Tabea Zimmermann Gibson  Überweisung an Regierungsrat
# 28  Tabea Zimmermann Gibson  Überweisung an Regierungsrat
# 29  Tabea Zimmermann Gibson      Nicht-Erheblicherklärung
# 30  Tabea Zimmermann Gibson  Überweisung an Regierungsrat
# 31  Tabea Zimmermann Gibson      Nicht-Erheblicherklärung
# 32  Tabea Zimmermann Gibson              Nichtüberweisung
# 33     Andreas Lustenberger  Überweisung an Regierungsrat
# 34     Andreas Lustenberger  Überweisung an Regierungsrat
# 35     Andreas Lustenberger    Antwort des Regierungsrats
# 36     Andreas Lustenberger  Überweisung an Regierungsrat
# 37     Andreas Lustenberger      Nicht-Erheblicherklärung
# 38     Andreas Lustenberger  Überweisung an Regierungsrat
# 39     Andreas Lustenberger    Antwort des Regierungsrats
#
#                        Zuständigkeit Art des Geschäfts         Status    P
# 0               Sicherheitsdirektion          Postulat         hängig  ALG
# 1               Direktion des Innern          Postulat         hängig  ALG
# 2                       Baudirektion    Interpellation         hängig  ALG
# 3   Direktion für Bildung und Kultur          Postulat  abgeschlossen  ALG
# 4                       Baudirektion          Postulat  abgeschlossen  ALG
# 5                    Finanzdirektion          Postulat  abgeschlossen  ALG
# 6   Direktion für Bildung und Kultur    Interpellation  abgeschlossen  ALG
# 7          Volkswirtschaftsdirektion    Kleine Anfrage  abgeschlossen  ALG
# 8          Volkswirtschaftsdirektion          Postulat  abgeschlossen  ALG
# 9                       Baudirektion    Interpellation  abgeschlossen  ALG
# 10  Direktion für Bildung und Kultur          Postulat  abgeschlossen  ALG
# 11  Direktion für Bildung und Kultur    Interpellation  abgeschlossen  ALG
# 12  Direktion für Bildung und Kultur    Kleine Anfrage  abgeschlossen  ALG
# 13  Direktion für Bildung und Kultur    Kleine Anfrage  abgeschlossen  ALG
# 14         Volkswirtschaftsdirektion    Interpellation  abgeschlossen  ALG
# 15                      Baudirektion    Interpellation  abgeschlossen  ALG
# 16              Direktion des Innern            Motion         hängig  ALG
# 17                      Baudirektion          Postulat         hängig  ALG
# 18  Direktion für Bildung und Kultur    Kleine Anfrage  abgeschlossen  ALG
# 19  Direktion für Bildung und Kultur          Postulat  abgeschlossen  ALG
# 20                   Finanzdirektion          Postulat  abgeschlossen  ALG
# 21              Gesundheitsdirektion    Interpellation  abgeschlossen  ALG
# 22              Sicherheitsdirektion    Kleine Anfrage  abgeschlossen  ALG
# 23  Direktion für Bildung und Kultur            Motion         hängig  ALG
# 24  Direktion für Bildung und Kultur    Kleine Anfrage  abgeschlossen  ALG
# 25  Direktion für Bildung und Kultur    Interpellation  abgeschlossen  ALG
# 26  Direktion für Bildung und Kultur    Interpellation  abgeschlossen  ALG
# 27              Direktion des Innern            Motion         hängig  Kt.
# 28              Direktion des Innern          Postulat         hängig  Kt.
# 29                   Finanzdirektion          Postulat         hängig  Kt.
# 30                      Baudirektion            Motion         hängig  Kt.
# 31  Direktion für Bildung und Kultur          Postulat  abgeschlossen  Kt.
# 32                   Finanzdirektion          Postulat  abgeschlossen  Kt.
# 33              Direktion des Innern            Motion         hängig  ALG
# 34                      Baudirektion          Postulat         hängig  ALG
# 35              Direktion des Innern    Kleine Anfrage  abgeschlossen  ALG
# 36                      Baudirektion    Interpellation         hängig  ALG
# 37                   Finanzdirektion          Postulat         hängig  ALG
# 38                      Baudirektion            Motion         hängig  ALG
# 39                   Finanzdirektion    Kleine Anfrage  abgeschlossen  ALG

# %%
# nun das df_alles noch abspeichern für den Endcode
df_alles.to_csv("KRFrames/Frame_mit_Namen_und_Parteien")

# %% [markdown]
# # IRRWEGE

# %%
nameliste=df_vs["Geschäft"].tolist()

# %%
nameliste
# Out:
# [['Luzian Franzini', 'Esther Haas'],
#  ['Luzian Franzini',
#   'Rita Hofer',
#   'Tabea Zimmermann Gibson',
#   'Andreas Lustenberger',
#   'Hanni Schriber-Neiger'],
#  ['Fabio Iten', 'Laura Dittli', 'Anna Bieri'],
#  ['Tabea Zimmermann Gibson', 'Stéphanie Vuichard', 'Esther Haas'],
#  ['SVP-Fraktion'],
#  ['SP-Fraktion'],
#  ['Ivo Egger',
#   'Stéphanie Vuichard',
#   'Hanni Schriber-Neiger',
#   'Andreas Lustenberger'],
#  ['Stéphanie Vuichard', 'Mariann Hess', 'Rita Hofer'],
#  ['Rainer Leemann', 'Michael Arnold'],
#  ['SP-Fraktion'],
#  ['Pirmin Andermatt', 'Heini Schmid'],
#  ['CVP-Fraktion'],
#  ['Manuela Leemann', 'Benny Elsener', 'Richard Rüegg'],
#  ['Hans Baumgartner',
#   'Manuela Käch',
#   'Jean Luc Mösch',
#   'Brigitte Wenzin Widmer',
#   'Rainer Suter',
#   'Thomas Gander',
#   'Drin Alaj',
#   'Petra Muheim Quick',
#   'Claus Soltermann'],
#  ['Pirmin Andermatt', 'Zari Dzaferi', 'Urs Andermatt'],
#  ['FDP-Fraktion'],
#  ['Andreas Lustenberger'],
#  ['CVP-Fraktion'],
#  ['FDP-Fraktion'],
#  ['Anna Bieri', 'Barbara Häseli'],
#  ['SP-Fraktion und'],
#  ['Fabio Iten', 'Patrick Iten'],
#  ['Ivo Egger', 'Zari Dzaferi'],
#  ['Rita Hofer'],
#  ['SP-Fraktion'],
#  ['Daniel Stadlin'],
#  ['Stéphanie Vuichard', 'Marianne Hess', 'Andreas Lustenberger'],
#  ['Anna Bieri', 'Manuela Leemann'],
#  ['Ivo Egger', 'Andreas Hürlimann', 'Anastas Odermatt'],
#  ['SVP-Fraktion'],
#  ['SP-Fraktion'],
#  ['SP-Fraktion'],
#  ['SP-Fraktion'],
#  ['Ivo Egger', 'Esther Haas', 'Hanni Schriber-Neiger'],
#  ['Tabea Zimmermann Gibson', 'Andreas Lustenberger', 'Mariann Hess'],
#  ['Manuela Leemann', 'Isabel Liniger'],
#  ['CVP-Fraktion'],
#  ['CVP-Fraktion'],
#  ['Michael Riboni', 'Laura Dittli', 'Michael Arnold'],
#  ['Stéphanie Vuichard', 'Isabel Liniger', 'Anna Spescha'],
#  ['Rischer Kantonsrätinnen und Kantonsräte',
#   'Helene Zimmermann',
#   'Hanni Schriber-Neiger',
#   'Steffen Schnei'],
#  ['SVP-Fraktion'],
#  ['Rainer Suter'],
#  ['CVP-Fraktion'],
#  ['Daniel Stadlin'],
#  ['Andreas Lustenberger',
#   'Tabea Zimmermann Gibson',
#   'Anastas Odermatt',
#   'Stéphanie Vuichard'],
#  ['Jean Luc Mösch', 'Laura Dittli', 'Thomas Meierhans'],
#  ['Jean Luc Mösch', 'Philip C. Brunner', 'Andreas Hausheer'],
#  ['Claus Soltermann', 'Daniel Stadlin', 'Martin Zimmermann', 'Nicole Zweifel'],
#  ['Alois Gössi', 'Anastas Odermatt', 'Philip C. Brunner'],
#  ['Karen Umbach', 'Beat Unternährer'],
#  ['Andreas Lustenberger'],
#  ['SVP-Fraktion'],
#  ['SVP-Fraktion'],
#  ['Beat Unternährer', 'Cornelia Stocker'],
#  ['Esther Haas',
#   'Rita Hofer',
#   'Anastas Odermatt',
#   'Vroni Straub-Müller',
#   'Tabea Zimmermann Gibson'],
#  ['Jean Luc Mösch', 'Manuela Käch', 'Hans Baumgartner'],
#  ['Laura Dittli', 'Fabio Iten', 'Patrick Iten'],
#  ['Kurt Balmer', 'Roger Wiederkehr', 'Pirmin Andermatt', 'Jean Luc Mösch'],
#  ['Jean Luc Mösch',
#   'Manuela Käch',
#   'Hans Baumgartner',
#   'Thomas Gander',
#   'Esther Haas',
#   'Claus Soltermann',
#   'Drin Alaj'],
#  ['Tabea Zimmermann Gibson',
#   'Vroni Straub-Müller',
#   'Stéphanie Vuichard',
#   'Esther Haas',
#   'Rita Hofer',
#   'Hanni Schriber-Neiger',
#   'Mariann Hess'],
#  ['Alois Gössi', 'Zari Dzaferi'],
#  ['Andreas Lustenberger',
#   'Vroni Straub-Müller',
#   'Andreas Hürlimann',
#   'Rita Hofer'],
#  ['Isabel Liniger', 'Anna Spescha'],
#  ['Rainer Suter'],
#  ['Philip C. Brunner'],
#  ['Kurt Balmer', 'Roger Wiederkehr'],
#  ['SP-Fraktion'],
#  ['Willi Vollenweider'],
#  ['Willi Vollenweider'],
#  ['Ralph Ryser',
#   'Zari Dzaferi',
#   'Barbara Häseli',
#   'Monika Weber',
#   'Thomas Werner',
#   'Beni Riedi'],
#  ['Rita Hofer'],
#  ['SP-Fraktion'],
#  ['Tempo 30 in der Zuger Innenstadt'],
#  ['Jürg Messmer', 'Richard Rüegg', 'Walter Birrer', 'Philip C. Brunner'],
#  ['SVP-Fraktion'],
#  ['Andreas Hürlimann', 'Philip C. Brunner'],
#  ['Philip C. Brunner'],
#  ['Hanni Schriber-Neiger', 'Andreas Hürlimann'],
#  ['Florian Weber', 'Daniel Abt'],
#  ['Andreas Hürlimann', 'Anastas Odermatt'],
#  ['Fraktion Alternative - die Grünen'],
#  ['Gabriela Ingold',
#   'Beat Unternährer',
#   'Florian Weber',
#   'Marcel Peter',
#   'Cornelia Stocker'],
#  ['SVP-Fraktion'],
#  ['Anna Bieri', 'Barbara Häseli'],
#  ['Rita Hofer', 'Vroni Straub-Müller'],
#  ['Anna Bieri',
#   'Zari Dzaferi',
#   'Rita Hofer',
#   'Claus Soltermann',
#   'Daniel Stuber',
#   'Oliver Wandfluh'],
#  ['Fraktion Alternative - die Grünen'],
#  ['Andreas Lustenberger'],
#  ['Marcel Peter'],
#  ['CVP-Fraktion'],
#  ['Andreas Hürlimann', 'Karen Umbach'],
#  ['Thomas Werner'],
#  ['CVP-Fraktion'],
#  ['Zari Dzaferi'],
#  ['Susanne Giger', 'Jürg Messmer', 'Willi Vollenweider'],
#  ['Moritz Schmid'],
#  ['Willi Vollenweider'],
#  ['Rita Hofer', 'Anastas Odermatt'],
#  ['Esther Haas'],
#  ['SVP-Fraktion'],
#  ['SP-Fraktion'],
#  ['SP-Fraktion'],
#  ['Fraktion Alternative - die Grünen'],
#  ['Anna Bieri', 'Laura Dittli'],
#  ['SP-Fraktion'],
#  ['Hans Baumgartner'],
#  ['SP-Fraktion'],
#  ['Beat Unternährer', 'Cornelia Stocker'],
#  ['Thomas Werner',
#   'René Kryenbühl',
#   'Ralph Ryser',
#   'Moritz Schmid',
#   'Karl Nussbaumer',
#   'Heini Schmid'],
#  ['FDP-Fraktion'],
#  ['Laura Dittli'],
#  ['Thomas Gander'],
#  ['SP-Fraktion'],
#  ['Willi Vollenweider'],
#  ['Gabriela Ingold',
#   'Beat Iten',
#   'Peter Letter',
#   'René Kryenbühl',
#   'Karl Nussbaumer',
#   'Mariann Hess',
#   'Marcel Peter',
#   'Thomas Werner'],
#  ['Fraktion Alternative - die Grünen'],
#  ['Fraktion Alternative - die Grünen'],
#  ['Laura Dittli', 'Patrick Iten', 'Iris Hess-Brauer'],
#  ['Vroni Straub-Müller'],
#  ['CVP-Fraktion'],
#  ['CVP-Fraktion'],
#  ['CVP-Fraktion'],
#  ['Andreas Lustenberger'],
#  ['Michael Riboni', 'Beni Riedi', 'Pirmin Andermatt', 'Andreas Hostettler'],
#  ['Karen Umbach'],
#  ['FDP-Fraktion'],
#  ['Fraktion Alternative - die Grünen'],
#  ['Andreas Lustenberger'],
#  ['Daniel Stadlin'],
#  ['Fraktion Alternative - die Grünen'],
#  ['CVP-Fraktion'],
#  ['Moritz Schmid'],
#  ['Beni Riedi', 'Michael Riboni'],
#  ['CVP-Fraktion'],
#  ['Beni Riedi', 'Florian Weber', 'Pirmin Andermatt'],
#  ['Andreas Hausheer', 'Manuel Brandenberg'],
#  ['Manuel Brandenberg', 'Philip C. Brunner'],
#  ['Kantonsrätin Monika Barmet'],
#  ['Karen Umbach', 'Philip C. Brunner'],
#  ['Pirmin Frei', 'Andreas Hausheer'],
#  ['Fraktion Alternative - die Grünen'],
#  ['Ralph Ryser'],
#  ['Fraktion Alternative - die Grünen'],
#  ['Fraktion Alternative - die Grünen'],
#  ['Staatswirtschaftskommission'],
#  ['SP-Fraktion'],
#  ['Beni Riedi', 'Florian Weber', 'Pirmin Andermatt'],
#  ['Fraktion Alternative - die Grünen'],
#  ['SVP-Fraktion'],
#  ['Daniel Marti'],
#  ['SVP-Fraktion'],
#  ['Fraktion Alternative - die Grünen'],
#  ['SP-Fraktion'],
#  ['Thomas Werner'],
#  ['Thomas Werner'],
#  ['René Kryenbühl', 'Karl Nussbaumer', 'Manuel Brandenberg'],
#  ['FDP-Fraktion'],
#  ['Jean-Luc Mösch', 'Rainer Suter', 'Thomas Gander'],
#  ['SVP-Fraktion'],
#  ['SVP-Fraktion'],
#  ['Daniel Stadlin'],
#  ['Beat Sieber'],
#  ['Peter Letter', 'Laura Dittli', 'Beat Unternährer'],
#  ['Jürg Messmer', 'Andreas Hostettler', 'Philip C. Brunner'],
#  ['Beni Riedi', 'Markus Hürlimann'],
#  ['Hubert Schuler'],
#  ['Jean-Luc Mösch', 'Silvan Renggli'],
#  ['Laura Dittli'],
#  ['Hans Baumgartner', 'Jean-Luc Mösch', 'Silvan Renggli'],
#  ['SVP-Fraktion'],
#  ['Andreas Hausheer', 'Thomas Meierhans'],
#  ['Andreas Hausheer', 'Thomas Meierhans', 'Daniel Burch'],
#  ['SP-Fraktion'],
#  ['Alois Gössi', 'Hubert Schuler'],
#  ['SP-Fraktion'],
#  ['Patrick Iten', 'Rainer Suter'],
#  ['Fraktion Alternative - die Grünen'],
#  ['Thomas Werner', 'Ralph Ryser', 'René Kryenbühl'],
#  ['Philip C. Brunner', 'Daniel Stadlin'],
#  ['Manuel Brandenberg'],
#  ['FDP-Fraktion'],
#  ['Alois Gössi', 'Anastas Odermatt'],
#  ['SVP-Fraktion'],
#  ['SVP-Fraktion'],
#  ['Barbara Gysel', 'Karen Umbach', 'Hans Baumgartner'],
#  ['Philip C. Brunner'],
#  ['Kurt Balmer'],
#  ['Anna Bieri', 'Remo Peduzzi'],
#  ['FDP-Fraktion'],
#  ['Philip C. Brunner', 'Walter Birrer'],
#  ['Nicole Imfeld'],
#  ['Esther Haas', 'Andreas Hausheer'],
#  ['Jean-Luc Mösch',
#   'Silvan Renggli',
#   'Hans Baumgartner',
#   'Rainer Suter',
#   'Walter Birrer',
#   'Esther Haas',
#   'Claus Soltermann',
#   'Beat Sieber',
#   'Thomas Gander',
#   'Thomas Meierhans',
#   'Monika Weber',
#   'Andreas Hürlimann',
#   'Anastas Odermatt',
#   'Philip C. Brunner'],
#  ['Philip C. Brunner'],
#  ['FDP-Fraktion'],
#  ['Fraktion Alternative - die Grünen'],
#  ['Philip C. Brunner'],
#  ['Esther Haas'],
#  ['Philip C. Brunner'],
#  ['Fraktion Alternative - die Grünen und'],
#  ['Fraktion Alternative - die Grünen'],
#  ['Daniel Stadlin'],
#  ['Willi Vollenweider'],
#  ['Zari Dzaferi', 'Andreas Lustenberger'],
#  ['Kurt Balmer', 'Laura Dittli'],
#  ['Michael Riboni', 'Laura Dittli', 'Anastas Odermatt'],
#  ['SVP-Fraktion'],
#  ['Monika Barmet', 'Andreas Etter', 'Karl Nussbaumer'],
#  ['Jolanda Spiess-Hegglin'],
#  ['Jolanda Spiess-Hegglin'],
#  ['Jolanda Spiess-Hegglin'],
#  ['Jolanda Spiess-Hegglin'],
#  ['Jolanda Spiess-Hegglin'],
#  ['Jolanda Spiess-Hegglin'],
#  ['Jolanda Spiess-Hegglin'],
#  ['Jolanda Spiess-Hegglin'],
#  ['Jolanda Spiess-Hegglin'],
#  ['Jolanda Spiess-Hegglin'],
#  ['Jolanda Spiess-Hegglin'],
#  ['Jolanda Spiess-Hegglin'],
#  ['Jolanda Spiess-Hegglin'],
#  ['Jolanda Spiess-Hegglin'],
#  ['Jolanda Spiess-Hegglin'],
#  ['Fraktion Alternative - die Grünen'],
#  ['Silvan Renggli', 'Jean-Luc Mösch'],
#  ['Fraktion Alternative - die Grünen'],
#  ['Florian Weber', 'Andreas Hürlimann', 'Philip C. Brunner'],
#  ['Daniel Thomas Burch',
#   'Andreas Hausheer',
#   'Manuel Brandenberg',
#   'Daniel Stadlin'],
#  ['Fraktion Alternative - die Grünen'],
#  ['Andreas Lustenberger'],
#  ['Andreas Lustenberger', 'Anastas Odermatt'],
#  ['Kurt Balmer'],
#  ['SP-Fraktion zum Gesetz über die Rechtsstellung'],
#  ['FDP-Fraktion'],
#  ['Fraktion Alternative – die Grünen'],
#  ['Jolanda Spiess-Hegglin'],
#  ['Jolanda Spiess-Hegglin'],
#  ['SVP-Fraktion'],
#  ['Michael Riboni', 'Markus Hürlimann'],
#  ['Claus Soltermann'],
#  ['Hubert Schuler'],
#  ['FDP-Fraktion'],
#  ['Thomas Werner', 'Karl Nussbaumer', 'Beni Riedi'],
#  ['Motion Daniel Stadlin'],
#  ['SVP-Fraktion'],
#  ['Patrick Iten'],
#  ['SVP-Fraktion'],
#  ['Monika Weber', 'Laura Dittli', 'Pirmin Frei'],
#  ['Kurt Balmer'],
#  ['Jolanda Spiess-Hegglin'],
#  ['Jolanda Spiess-Hegglin'],
#  ['Fraktion Alternative - die Grünen'],
#  ['CVP-Fraktion'],
#  ['Andreas Hausheer', 'Pirmin Frei'],
#  ['CVP-Fraktion'],
#  ['Peter Letter',
#   'Laura Dittli',
#   'Iris Hess-Brauer',
#   'Gabriela Ingold',
#   'Patrick Iten',
#   'Thomas Werner'],
#  ['Daniel Marti'],
#  ['Daniel Stadlin', 'Richard Rüegg'],
#  ['SP-Fraktion'],
#  ['Philip C. Brunner'],
#  ['SP-Fraktion'],
#  ['CVP-Fraktion'],
#  ['CVP-Fraktion'],
#  ['Jolanda Spiess-Hegglin'],
#  ['Markus Hürlimann', 'Michael Riboni'],
#  ['SP-Fraktion zum EG AuG (BGS 122.5)'],
#  ['Fraktion Alternative - die Grünen'],
#  ['Ralph Ryser', 'Karl Nussbaumer', 'Thomas Werner'],
#  ['SP-Fraktion'],
#  ['Andreas Lustenberger'],
#  ['Fraktion Alternative - die Grünen'],
#  ['Justizprüfungskommission'],
#  ['Cornelia Stocker', 'Daniel Abt'],
#  ['Philip C. Brunner', 'Jürg Messmer'],
#  ['Andreas Hürlimann', 'Philip C. Brunner'],
#  ['Fraktion Alternative – die Grünen'],
#  ['Jolanda Spiess-Hegglin'],
#  ['Richard Rüegg'],
#  ['Kurt Balmer',
#   'Heini Schmid',
#   'Manuel Brandenberg',
#   'Thomas Lötscher',
#   'Anastas Odermatt'],
#  ['Peter Letter',
#   'Philip C. Brunner',
#   'Daniel Thomas Burch',
#   'Daniel Marti',
#   'Thomas Meierhans',
#   'Karl Nussbaumer',
#   'Cornelia Stocker',
#   'Silvia Thalmann'],
#  ['SP-Fraktion'],
#  ['Rainer Suter'],
#  ['Philip C. Brunner', 'Manuel Brandenberg'],
#  ['Manuel Brandenberg',
#   'Philip C. Brunner',
#   'Markus Hürlimann',
#   'Peter Letter',
#   'Thomas Meierhans',
#   'Karl Nussbaumer',
#   'Cornelia Stocker',
#   'Silvia Thalmann',
#   'Florian Weber'],
#  ['Markus Hürlimann', 'Michael Riboni'],
#  ['SP-Fraktion'],
#  ['Philip C. Brunner', 'Manuel Brandenberg'],
#  ['Thomas Lötscher',
#   'Thomas Gander',
#   'Daniel Stuber',
#   'Karen Umbach',
#   'Monika \r\nWeber',
#   'Claus Soltermann',
#   'Willi Vollenweider'],
#  ['Barbara Gysel',
#   'Karin Andenmatten-Helbling',
#   'Anna Bieri',
#   'Nicole Imfeld',
#   'Gabriela Ingold',
#   'Hanni Schriber-Neiger',
#   'Karen Umbach'],
#  ['Esther Haas',
#   'Andreas Hostettler',
#   'Peter Letter',
#   'Beat Unternährer',
#   'Beat Iten',
#   'Zari Dzaferi',
#   'Pirmin Andermatt',
#   'Karin Andenmatten-Helbling'],
#  ['Daniel Stadlin'],
#  ['Manuel Brandenberg',
#   'Jürg Messmer',
#   'Karl Nussbaumer',
#   'Moritz Schmid',
#   'Beat Sieber',
#   'Thomas Villiger'],
#  ['Andreas Etter'],
#  ['Silvan Renggli', 'Daniel Thomas Burch', 'Jean-Luc Mösch'],
#  ['Pirmin Frei', 'Daniel Abt', 'Walter Birrer'],
#  ['SP-Fraktion'],
#  ['Beat Unternährer'],
#  ['Hubert Schuler'],
#  ['Daniel Stadlin'],
#  ['Jean-Luc Mösch', 'Silvan Renggli', 'Patrick Iten', 'Kurt Balmer'],
#  ['Nicole Imfeld', 'Daniel Marti', 'Claus Soltermann', 'Daniel Stadlin'],
#  ['Alice Landtwing', 'Karen Umbach'],
#  ['Esther Haas', 'Rita Hofer', 'Anastas Odermatt'],
#  ['Kurt Balmer', 'Andreas Hausheer'],
#  ['Andreas Lustenberger', 'Beni Riedi'],
#  ['Jean-Luc Mösch', 'Silvan Renggli'],
#  ['CVP-Fraktion'],
#  ['Manuel Brandenberg', 'Markus Hürlimann'],
#  ['Philip C. Brunner', 'Daniel Stadlin', 'Cornelia Stocker', 'Urs Raschle'],
#  ['Zari Dzaferi'],
#  ['Zari Dzaferi'],
#  ['SP-Fraktion'],
#  ['Willi Vollenweider', 'Philip C. Brunner'],
#  ['SVP-Fraktion'],
#  ['Daniel Stadlin'],
#  ['SVP-Fraktion'],
#  ['Andreas Hausheer'],
#  ['SP-Fraktion'],
#  ['Fraktionen'],
#  ['Fraktion Alternative - die Grünen (ALG)'],
#  ['CVP-Fraktion'],
#  ['Esther Haas'],
#  ['Alois Gössi'],
#  ['SVP-Fraktion'],
#  ['Michèle Kottelat'],
#  ['Thomas Werner', 'Beni Riedi'],
#  ['Anna Bieri', 'Laura Dittli'],
#  ['Michael Riboni', 'Beni Riedi', 'Thomas Villiger', 'Thomas Werner'],
#  ['Michèle Kottelat'],
#  ['SP-Fraktion'],
#  ['Andreas Lustenberger'],
#  ['Thomas Meierhans'],
#  ['Denkmalpflege im Kanton Zug (Teilumwandlung'],
#  ['Denkmalpflege im Kanton Zug (Teilumwandlung'],
#  ['Fraktion Alternative - Die Grünen'],
#  ['Thomas Lötscher'],
#  ['Willi Vollenweider'],
#  ['Laura Dittli'],
#  ['Manuel Brandenberg', 'Heini Schmid'],
#  ['Daniel Stadlin'],
#  ['Andreas Hostettler',
#   'Monika Weber',
#   'Peter Letter',
#   'Karen Umbach',
#   'Beat Unternährer'],
#  ['SVP-Fraktion'],
#  ['Jean-Luc Mösch'],
#  ['SVP-Fraktion'],
#  ['Rainer Suter', 'Gabriela Ingold', 'Andreas Hausheer'],
#  ['Gabriela Ingold', 'Thomas Lötscher', 'Beat Unternährer'],
#  ['Kurt Balmer', 'Flavio Roos', 'Barbara Gysel'],
#  ['CVP-Fraktion'],
#  ['SP-Fraktion'],
#  ['Fraktion Alternative - die Grünen'],
#  ['Florian Weber', 'Andreas Hürlimann', 'Philip C. Brunner'],
#  ['Thomas Werner'],
#  ['Daniel Abt'],
#  ['Barbara Gysel'],
#  ['FDP-Fraktion'],
#  ['Staatswirtschaftskommission'],
#  ['Adrian Andermatt', 'Daniel Thomas Burch'],
#  ['SP-Fraktion'],
#  ['SVP-Fraktion'],
#  ['Jürg Messmer', 'Philip C. Brunner', 'Manuel Brandenberg'],
#  ['Thomas Lötscher'],
#  ['Andreas Hausheer'],
#  ['Anna Bieri'],
#  ['Andreas Hausheer'],
#  ['Manuel Brandenberg',
#   'Philip C. Brunner',
#   'Beni Riedi',
#   'Rainer Suter',
#   'Thomas Werner'],
#  ['Rainer Suter'],
#  ['Silvan Hotz'],
#  ['FDP-Fraktion'],
#  ['Ivo Hunn'],
#  ['SP-Fraktion'],
#  ['SP-Fraktion'],
#  ['SP-Fraktion'],
#  ['SP-Fraktion'],
#  ['SP-Fraktion'],
#  ['SP-Fraktion'],
#  ['SP-Fraktion'],
#  ['SP-Fraktion'],
#  ['SP-Fraktion'],
#  ['Thiemo Hächler', 'Daniel Abt', 'Manuel Brandenberg'],
#  ['SP-Fraktion'],
#  ['Stadtzuger Kantonsrätinnen und Kantonsräte'],
#  ['Stadtzuger Kantonsrätinnen und Kantonsräte'],
#  ['SP-Fraktion'],
#  ['Silvan Hotz', 'Irène Castell-Bachmann', 'Franz Peter Iten', 'Daniel Abt'],
#  ['Beni Riedi', 'Thomas Werner'],
#  ['Kurt Balmer'],
#  ['Kurt Balmer'],
#  ['Alternativen Grünen Fraktion'],
#  ['CVP-Fraktion'],
#  ['CVP-Fraktion'],
#  ['Stefan Gisler', 'Andreas Hausheer', 'Manuel Brandenberg'],
#  ['Alois Gössi',
#   'Andreas Hürlimann',
#   'Florian Weber',
#   'Vreni Wicky',
#   'Thomas Wyss'],
#  ['Andreas Hausheer'],
#  ['Silvan Hotz'],
#  ['CVP-Fraktion'],
#  ['CVP-Fraktion'],
#  ['FDP-Fraktion'],
#  ['Daniel Stadlin'],
#  ['Kurt Balmer'],
#  ['Andreas Lustenberger'],
#  ['Andreas Hausheer'],
#  ['Daniel Abt', 'Adrian Andermatt'],
#  ['SP-Fraktion'],
#  ['Georg Helfenstein'],
#  ['Zari Dzaferi', 'Bernadette Flach', 'Esther Haas', 'Martin Pfister'],
#  ['Manuel Brandenberg'],
#  ['Andreas Hausheer'],
#  ['Andreas Lustenberger'],
#  ['Kommission zur Totalrevision'],
#  ['Manfred Wenger'],
#  ['Manfred Wenger'],
#  ['ad-hoc Kommission zur Untersuchung'],
#  ['ad-hoc Kommission zur Untersuchung'],
#  ['SP-Fraktion'],
#  ['Philip C. Brunner'],
#  ['Daniel Stadlin'],
#  ['Andreas Hausheer', 'Gabriela Ingold'],
#  ['Gabriela Ingold', 'Thomas Lötscher', 'Leonie Winter'],
#  ['Gabriela Ingold', 'Thomas Lötscher', 'Leonie Winter'],
#  ['Kurt Balmer'],
#  ['CVP-Fraktion'],
#  ['CVP-Fraktion'],
#  ['Daniel Abt', 'Karl Nussbaumer', 'Andreas Hausheer'],
#  ['Karin Andenmatten-Helbling',
#   'Alois Gössi',
#   'Andreas Hürlimann',
#   'Thomas Lötscher',
#   'Thomas Wyss'],
#  ['Alternativen Grünen Fraktion'],
#  ['Manfred Wenger'],
#  ['FDP- und'],
#  ['Martin Stuber', 'Philip C. Brunner', 'Florian Weber'],
#  ['SVP-Fraktion'],
#  ['Eusebius Spescha', 'Zari Dzaferi'],
#  ['Eusebius Spescha', 'Zari Dzaferi'],
#  ['Daniel Stadlin'],
#  ['SP-Fraktion'],
#  ['SVP-Fraktion'],
#  ['Alternativen Grünen Fraktion'],
#  ['Mario Reinschmidt', 'Monika Weber'],
#  ['CVP-Fraktion'],
#  ['Manfred Wenger'],
#  ['Manfred Wenger zur Beantwortung der Kleinen Anfrage'],
#  ['Eugen Meienberg', 'Andreas Hausheer'],
#  ['Alternativen Grünen Fraktion und'],
#  ['Alternativen Grünen Fraktion'],
#  ['FDP-Fraktion'],
#  ['Philip C. Brunner', 'Jürg Messmer'],
#  ['Manuel Brandenberg', 'Philip C. Brunner', 'Jürg Messmer', 'Manfred Wenger'],
#  ['Gregor Kupper'],
#  ['Monika Barmet', 'Frowin Betschart'],
#  ['Anna Bieri', 'Martin Stuber'],
#  ['Daniel Abt'],
#  ['Manuel Brandenberg'],
#  ['Jürg Messmer', 'Beni Riedi', 'Roland'],
#  ['Konkordatskommission'],
#  ['Thomas Werner'],
#  ['Thomas Werner'],
#  ['SVP-Fraktion'],
#  ['Andreas Hausheer'],
#  ['Thiemo Hächler', 'Daniel Abt', 'Manuel Brandenberg'],
#  ['Alternativen Grünen Fraktion'],
#  ['Manfred Wenger'],
#  ['Jürg Messmer', 'Philip C. Brunner'],
#  ['Alternativen Grünen Fraktion'],
#  ['Franz Peter Iten', 'Pirmin Frei'],
#  ['Alternativen Grünen Fraktion'],
#  ['Esther Haas', 'Andreas Lustenberger'],
#  ['Manfred Wenger'],
#  ['Konkordatskommission'],
#  ['Martin Stuber'],
#  ['Esther Haas'],
#  ['SVP-Fraktion'],
#  ['Daniel Thomas Burch'],
#  ['Philip C. Brunner'],
#  ['Daniel Thomas Burch', 'Thomas Lötscher'],
#  ['Beni Riedi'],
#  ['Alternativen Grünen Fraktion'],
#  ['CVP-Fraktion'],
#  ['Manfred Wenger'],
#  ['Beni Riedi'],
#  ['Franz Hürlimann'],
#  ['Manuel Brandenberg', 'Jürg Messmer'],
#  ['Kurt Balmer'],
#  ['Thomas Lötscher'],
#  ['SVP-Fraktion'],
#  ['Staatswirtschaftskommission'],
#  ['CVP-Fraktion'],
#  ['CVP-Fraktion'],
#  ['CVP-Fraktion'],
#  ['Stefan Gisler zu Aussagen des Bildungsdirektors bezüglich familienergänzender Kinderbetreuung'],
#  ['SVP-Fraktion'],
#  ['SVP-Fraktion'],
#  ['SVP-Fraktion'],
#  ['Andreas Hausheer'],
#  ['Philip C. Brunner'],
#  ['Urs Raschle'],
#  ['Anna Lustenberger-Seitz', 'Stefan Gisler'],
#  ['Thomas Lötscher'],
#  ['FDP-Fraktion'],
#  ['Andreas Hausheer', 'Manuel Brandenberg', 'Daniel Thomas Burch'],
#  ['SP-Fraktion'],
#  ['Beni Riedi'],
#  ['CVP-Fraktion'],
#  ['Daniel Stadlin', 'Philip C. Brunner'],
#  ['Florian Weber', 'Franz Hürlimann'],
#  ['SP-Fraktion'],
#  ['Daniel Stadlin'],
#  ['Daniel Stadlin'],
#  ['Alternativen Grünen Fraktion'],
#  ['Martin Stuber', 'Florian Weber'],
#  ['Gabriela Peita'],
#  ['CVP-Fraktion'],
#  ['Jürg Messmer', 'Philip C. Brunner'],
#  ['SP-Fraktion'],
#  ['Kurt Balmer'],
#  ['Daniel Stadlin'],
#  ['SP-Fraktion'],
#  ['Eusebius Spescha'],
#  ['Franz Peter Iten', 'Christine Blättler-Müller', 'Andreas Hausheer'],
#  ['Markus Jans'],
#  ['CVP-Fraktion'],
#  ['SP-Fraktion'],
#  ['SP-Fraktion'],
#  ['Cornelia Stocker', 'Alice Landtwing'],
#  ['Zari Dzaferi'],
#  ['vorberatenden Kommission zum Pensionskassengesetz'],
#  ['Gabriela Ingold'],
#  ['SVP-Fraktion'],
#  ['Thomas Werner'],
#  ['vorberatenden Kommission zur Än'],
#  ['Gabriela Ingold', 'Barbara Strub'],
#  ['Moritz Schmid'],
#  ['CVP-Fraktion'],
#  ['Andreas Hausheer', 'Eugen Meienberg'],
#  ['Anna Bieri'],
#  ['SVP-Fraktion'],
#  ['Kurt Balmer'],
#  ['Jürg Messmer', 'Philip C. Brunner'],
#  ['Philip C. Brunner', 'Martin Stuber', 'Zari Dzaferi'],
#  ['Thomas Villiger'],
#  ['Georg Helfenstein', 'Kurt Balmer'],
#  ['Vreni Wicky', 'Andreas Hausheer'],
#  ['André Wicki', 'Manuel Brandenberg'],
#  ['Adrian Andermatt'],
#  ['Hubert Schuler'],
#  ['Thomas Lötscher'],
#  ['SVP-Fraktion'],
#  ['SP-Fraktion'],
#  ['Zari Dzaferi'],
#  ['vorberatenden Kommission zum Integrationsgesetz'],
#  ['André Wicki'],
#  ['SP-Fraktion'],
#  ['Daniel Stadlin'],
#  ['Alternativen Grünen Fraktion'],
#  ['SP-Fraktion'],
#  ['Daniel Stadlin'],
#  ['Andreas Hürlimann'],
#  ['Leonie Winter', 'Thiemo Hächler', 'Oliver Wandfluh'],
#  ['Thomas Lötscher'],
#  ['André Wicki'],
#  ['Thomas Aeschi'],
#  ['Thomas Werner'],
#  ['Karin Andenmatten', 'Anna Bieri'],
#  ['Thomas Aeschi'],
#  ['Thomas Aeschi'],
#  ['Andreas Hausheer'],
#  ['Alternativen Grünen Fraktion'],
#  ['Alternativen Grünen Fraktion'],
#  ['Pirmin Frei'],
#  ['SVP-Fraktion'],
#  ['Manuel Brandenberg', 'Philip C. Brunner'],
#  ['SP-Fraktion'],
#  ['Beda Schlumpf', 'Daniel Abt'],
#  ['Philip C. Brunner'],
#  ['SVP-Fraktion'],
#  ['Martin Stuber', 'Philip C. Brunner'],
#  ['Kurt Balmer'],
#  ['Thomas Rickenbacher'],
#  ['Alternativen Grünen Fraktion'],
#  ['SP- und'],
#  ['Thomas Aeschi'],
#  ['Daniel Stadlin'],
#  ['Andreas Hausheer'],
#  ['Anna Lustenberger-Seitz'],
#  ['Daniel Thomas Burch', 'Kurt Balmer'],
#  ['Kurt Balmer', 'Georg Helfenstein'],
#  ['Eusebius Spescha', 'Zari Dzaferi'],
#  ['Daniel Stadlin'],
#  ['Menzinger Kantonsratsmitglie'],
#  ['Daniel Thomas Burch',
#   'Cornelia Stocker',
#   'Adrian Andermatt',
#   'Maja Dübendorfer Christen',
#   'Karin Andenmatten',
#   'Anna Bieri',
#   'Silvia Thalmann'],
#  ['Oliver Wandfluh'],
#  ['Philippe Camenisch',
#   'Cornelia Stocker',
#   'Alice Landtwing',
#   'Adrian Andermatt',
#   'Maja Dübendorfer Christen'],
#  ['Manuel Brandenberg'],
#  ['Thomas Lötscher'],
#  ['Kommission Polycom zum Kantonsratsbeschluss'],
#  ['Justizprüfungskommission'],
#  ['SVP-Fraktion'],
#  ['Philip C. Brunner',
#   'André Wicki',
#   'Manuel Brandenberg',
#   'Daniel Burch',
#   'Thomas Wyss'],
#  ['Thiemo Hächler', 'Cornelia Stocker', 'André Wicki'],
#  ['Thomas Aeschi'],
#  ['Zari Dzaferi'],
#  ['Thomas Wyss', 'Werner Villiger', 'Roland'],
#  ['Vroni Straub-Müller', 'Anna Lustenberger-Seitz'],
#  ['Christine Blättler-Müller', 'Georg Helfenstein', 'Thomas Rickenbacher'],
#  ['Andreas Hausheer'],
#  ['Philippe Camenisch', 'Cornelia Stocker'],
#  ['Alois Gössi'],
#  ['Martin Pfister',
#   'Martin B. Lehmann',
#   'Anna Lustenberger-Seitz',
#   'Moritz Schmid',
#   'Daniel Stadlin'],
#  ['Andreas Hürlimann', 'Stefan Gisler'],
#  ['Karin Andenmatten', 'Anna Bieri'],
#  ['Hubert Schuler', 'Karin Andenmatten', 'Thomas Villiger'],
#  ['Arthur Walker', 'Dominik Lehner'],
#  ['Moritz Schmid'],
#  ['Kurt Balmer'],
#  ['Manuel Brandenberg', 'Philip C. Brunner'],
#  ['Daniel Stadlin'],
#  ['Beni Riedi', 'Thomas Aeschi'],
#  ['Karl Nussbaumer', 'Thomas Werner'],
#  ['Daniel Stadlin'],
#  ['Manuel Brandenberg', 'Philip C. Brunner'],
#  ['Alois Gössi', 'Zari Dzaferi'],
#  ['Alternativen Grünen Fraktion und'],
#  ['Thomas Lötscher',
#   'Philippe Camenisch',
#   'Daniel Abt',
#   'Daniel Thomas Burch'],
#  ['Beni Riedi'],
#  ['SP-Fraktion'],
#  ['Daniel Stadlin'],
#  ['Manuel Brandenberg',
#   'Philip C. Brunner',
#   'Thomas Wyss',
#   'Werner Villiger',
#   'André Wicki',
#   'Daniel Eichenberger',
#   'Beni Riedi',
#   'Manuel Aeschbacher',
#   'Thomas Werner',
#   'Daniel Burch',
#   'Matthias Werder'],
#  ['Gregor Kupper'],
#  ['Cornelia Stocker', 'Maja Dübendorfer Christen'],
#  ['Pirmin Frei'],
#  ['Manuel Brandenberg', 'Thomas Wyss'],
#  ['Daniel Abt', 'Beda Schlumpf'],
#  ['Kurt Balmer', 'Franz Hürlimann'],
#  ['Raumplanungskommission'],
#  ['Alternativen Grünen Fraktion und'],
#  ['SP-Fraktion'],
#  ['Franz Hürlimann'],
#  ['Irène Castell-Bachmann', 'Martin Pfister'],
#  ['Thomas Aeschi'],
#  ['Thomas Aeschi'],
#  ['Anna Bieri', 'Frowin Betschart'],
#  ['Beni Riedi'],
#  ['Fraktion Alternative - Die Grünen'],
#  ['Beat Sieber',
#   'Daniel Thomas Burch',
#   'Barbara Strub',
#   'Dominik Lehner',
#   'Monika Weber',
#   'Thomas Lötscher'],
#  ['Kurt Balmer'],
#  ['Georg Helfenstein'],
#  ['Karl Nussbaumer', 'Thomas Wyss', 'Manuel Brandenberg'],
#  ['Fraktion Alternative - Die Grünen'],
#  ['Hans Christen',
#   'Zari Dzaferi',
#   'Heini Schmid',
#   'Daniel Stadlin',
#   'Martin Stuber',
#   'Werner Villiger'],
#  ['Kurt Balmer', 'Anna Bieri', 'Karin Andenmatten'],
#  ['SVP-Fraktion'],
#  ['Urs Raschle'],
#  ['CVP-Fraktion'],
#  ['CVP-Fraktion'],
#  ['Manuel Brandenberg', 'Philip C. Brunner', 'Daniel Burch', 'Thomas Wyss'],
#  ['Rudolf Balsiger', 'Moritz Schmid'],
#  ['Christina Huber Keiser',
#   'Erwina Winiger',
#   'Monika Barmet',
#   'Eusebius Spescha',
#   'Andreas Hürlimann',
#   'Arthur Walker'],
#  ['Silvan Hotz', 'Daniel Grunder'],
#  ['Moritz Schmid'],
#  ['Georg Helfenstein', 'Silvan Hotz'],
#  ['Anton Stöckli', 'Moritz Schmid'],
#  ['Moritz Schmid'],
#  ['Thomas Brändle', 'Thomas Lötscher'],
#  ['Thiemo Hächler'],
#  ['Hanni Schriber-Neiger'],
#  ['Hanni Schriber-Neiger', 'Martin Stuber'],
#  ['Thomas Lötscher'],
#  ['CVP-Fraktion'],
#  ['Stefan Gisler', 'Vroni Straub-Müller', 'Martin Stuber'],
#  ['Beat Sieber', 'Peter Diehm'],
#  ['CVP-Fraktion'],
#  ['Felix Häcki'],
#  ['Thomas Lötscher', 'Philippe Camenisch', 'Daniel Abt', 'Daniel Burch'],
#  ['CVP-Fraktion'],
#  ['CVP-Fraktion'],
#  ['Thiemo Hächler'],
#  ['Hanni Schriber-Neiger'],
#  ['Bettina Egler'],
#  ['Philipp Röllin'],
#  ['Berty Zeiter', 'Eric Frischknecht', 'Martin Stuber'],
#  ['FDP-Fraktion'],
#  ['Thomas Lötscher'],
#  ['Rudolf Balsiger'],
#  ['Stefan Gisler', 'Andreas Hürlimann'],
#  ['SP-Fraktion'],
#  ['Vroni Straub-Müller', 'Stefan Gisler'],
#  ['Martin Stuber'],
#  ['Manuel Aeschbacher'],
#  ['SP- und'],
#  ['FDP-Fraktion'],
#  ['Andreas Hausheer', 'Rudolf Balsiger'],
#  ['CVP-Fraktion'],
#  ['erweiterten Justizprüfungskommission'],
#  ['erweiterten Justizprüfungskommission'],
#  ['Generalsekretär den aktuellen Stand sämtlicher wichtiger Geschäfte kennt und verpflichtet ist',
#   'bei Ausfall des Direktionsvorstehers dem stv. RR-Mitglied die nötigen Infos weiterzugeben'],
#  ['erweiterten Jusitzprüfungskommission'],
#  ['Silvan Hotz'],
#  ['SVP-Fraktion'],
#  ['Silvan Hotz'],
#  ['SVP-Fraktion'],
#  ['SVP-Fraktion'],
#  ['Albert C. Iten'],
#  ['erweiterten Justizprüfungskommission'],
#  ['Franz Hürlimann'],
#  ['Vreni Wicky'],
#  ['Manuel Aeschbacher',
#   'Monika Barmet',
#   'Daniel Grunder',
#   'Stefan Gisler',
#   'Christina Huber Keiser'],
#  ['Martin Stuber', 'Heini Schmid', 'Thomas Lötscher'],
#  ['Alternativen Grünen Fraktion'],
#  ['Moritz Schmid', 'Rudolf Balsiger'],
#  ['Alternativen Grünen Fraktion'],
#  ['SP-Fraktion'],
#  ['Martin B. Lehmann'],
#  ['Werner Villiger', 'Rudolf Balsiger', 'Moritz Schmid'],
#  ['Alternativen Grünen Fraktion und'],
#  ['Eric Frischknecht', 'Hanni Schriber-Neiger', 'Andreas Hürlimann'],
#  ['Rudolf Balsiger', 'Thomas Lötscher'],
#  ['Alternativen Grünen Fraktion und'],
#  ['SVP-Fraktion'],
#  ['Gabriela Ingold', 'Barbara Strub'],
#  ['Stephan Schleiss'],
#  ['Martin Pfister', 'Daniel Grunder'],
#  ['Alternativen Grünen Fraktion'],
#  ['Silvan Hotz', 'Irène Castell-Bachmann'],
#  ['Alternativen Grünen Fraktion und'],
#  ['SP-Fraktion'],
#  ['Franz Hürlimann'],
#  ['Christina Huber Keiser', 'Andreas Hürlimann'],
#  ['Andreas Hausheer'],
#  ['SVP-Fraktion'],
#  ['FDP-Fraktion'],
#  ['Alternativen Fraktion'],
#  ['Martin B. Lehmann'],
#  ['SP-Fraktion'],
#  ['SVP-Fraktion'],
#  ['CVP-Fraktion'],
#  ['CVP Fraktion'],
#  ['CVP-Fraktion'],
#  ['CVP-Fraktion'],
#  ['Martin B. Lehmann'],
#  ['Alois Gössi'],
#  ['Bettina Egler', 'Berty Zeiter'],
#  ['Stephan Schleiss', 'Manuel Aeschbacher'],
#  ['Vreni Wicky', 'Georg Helfenstein', 'Markus Scheidegger', 'Silvan Hotz'],
#  ['CVP-Fraktion'],
#  ['Vroni Straub-Müller'],
#  ['FDP-Fraktion'],
#  ['Silvan Hotz'],
#  ['Martin Stuber'],
#  ['Moritz Schmid'],
#  ['Alternativen Fraktion'],
#  ['Silvan Hotz'],
#  ['Silvan Hotz'],
#  ['Rupan Sivaganesan'],
#  ['Rudolf Balsiger', 'Moritz Schmid'],
#  ['Stephan Schleiss'],
#  ['FDP-Fraktion'],
#  ['Eusebius Spescha'],
#  ['Moritz Schmid'],
#  ['Franz Peter Iten',
#   'Arthur Walker',
#   'Thomas Brändle',
#   'Thiemo Hächler',
#   'Guido Heinrich',
#   'Moritz Schmid'],
#  ['Eusebius Spescha', 'Vroni Straub-Müller'],
#  ['Martin B. Lehmann'],
#  ['FDP-Fraktion zum Ausbau'],
#  ['Bettina Egler'],
#  ['Alternativen Fraktion'],
#  ['Barbara Gysel'],
#  ['SP-Fraktion'],
#  ['CVP-Fraktion'],
#  ['FDP-Fraktion'],
#  ['Hubert Schuler gegen Ärztemangel', 'zur Förderung der Hausarztmedizin'],
#  ['Daniel Abt'],
#  ['Martin Pfister', 'Josef Murer'],
#  ['Rudolf Balsiger'],
#  ['Alternativen Fraktion'],
#  ['Fredy Abächerli', 'Monika Barmet', 'Franz Hürlimann', 'Karl Nussbaumer'],
#  ['Andreas Hürlimann'],
#  ['Alternativen Fraktion'],
#  ['SP-Fraktion'],
#  ['FDP-Fraktion zur Abschaffung'],
#  ['FDP-Fraktion für eine jährliche Anpassung'],
#  ['Christina Huber Keiser', 'Martin Stuber'],
#  ['Franz Hürlimann', 'Thiemo Hächler'],
#  ['Daniel Burch'],
#  ['SP-Fraktion'],
#  ['Alois Gössi', 'Hubert Schuler'],
#  ['Gregor Kupper'],
#  ['Martin B. Lehmann', 'Barbara Gysel'],
#  ['SP-Fraktion'],
#  ['SVP-Fraktion'],
#  ['Alternativen Fraktion'],
#  ['Barbara Strub'],
#  ['CVP-Fraktion'],
#  ['Erwina Winiger'],
#  ['SVP-Fraktion'],
#  ['Beni Langenegger', 'Beat Zürcher'],
#  ['Anna Lustenberger-Seitz', 'Vroni Straub-Müller'],
#  ['Alternativen Fraktion'],
#  ['Karin Julia Stadlin', 'Barbara Strub', 'Regula Töndury'],
#  ['FDP-Fraktion'],
#  ['CVP-Fraktion'],
#  ['SP-Fraktion'],
#  ['FDP-Fraktion'],
#  ['Karin Andenmatten'],
#  ['Markus Jans'],
#  ['SVP-Fraktion'],
#  ['SP-Fraktion'],
#  ['SVP-Fraktion'],
#  ['Hubert Schuler',
#   'Karin Andenmatten',
#   'Eric Frischknecht',
#   'Andreas Huwyler',
#   'Thomas Villiger',
#   'Leonie Winter'],
#  ['Vreni Wicky',
#   'Rudolf Balsiger',
#   'Philippe Camenisch',
#   'Albert C. Iten',
#   'Rupan Sivaganesan',
#   'Eusebius Spescha',
#   'Werner Villiger'],
#  ['CVP-Fraktion'],
#  ['digitalen', 'audio-visuellen Medien', 'einem Verkaufsverbot'],
#  ['Thomas Lötscher'],
#  ['Martin B. Lehmann'],
#  ['Karl Nussbaumer', 'Stephan Schleiss'],
#  ['Alternativen Fraktion'],
#  ['Andreas Hausheer'],
#  ['SP-Fraktion'],
#  ['Martin Stuber',
#   'Vroni Straub-Müller',
#   'Rupan Sivaganesan',
#   'Stefan Gisler'],
#  ['Andreas Hausheer'],
#  ['Bettina Egler', 'Eusebius Spescha', 'Markus Jans', 'Hubert Schuler'],
#  ['SP-Fraktion'],
#  ['CVP-Fraktion'],
#  ['CVP-Fraktion'],
#  ['Alois Gössi', 'Bettina Egler', 'Eusebius Spescha'],
#  ['Anna Lustenberger-Seitz',
#   'Georg Helfenstein',
#   'Manuel Aeschbacher ("IG Ganzheitliche Bildung")'],
#  ['Vroni Straub-Müller', 'Anna Lustenberger-Seitz'],
#  ['Thomas Villiger', 'Karl Nussbaumer', 'Manuel Aeschbacher'],
#  ['SVP-Fraktion'],
#  ['Alternativen Fraktion und'],
#  ['Stephan Schleiss', 'Werner Villiger'],
#  ['Vreni Wicky'],
#  ['Alternativen Fraktion'],
#  ['Alternativen Fraktion'],
#  ['Alois Gössi', 'Anna Lustenberger-Seitz'],
#  ['Martin B. Lehmann',
#   'Thomas Lötscher',
#   'Thomas Rickenbacher',
#   'Karl Nussbaumer',
#   'Rupan Sivaganesan'],
#  ['CVP-Fraktion'],
#  ['Max Uebelhart', 'Vreni Wicky'],
#  ['Martin B. Lehmann'],
#  ['Alternativen Fraktion und'],
#  ['SP- und'],
#  ['Anna Lustenberger-Seitz', 'Berty Zeiter'],
#  ['Christina Bürgi Dellsperger'],
#  ['Markus Jans', 'Hubert Schuler'],
#  ['Thomas Lötscher'],
#  ['SVP-Fraktion'],
#  ['CVP-Fraktion'],
#  ['Vreni Wicky'],
#  ['CVP-Fraktion'],
#  ['Personalcomputern"'],
#  ['Markus Jans'],
#  ['Alternativen Fraktion'],
#  ['Berty Zeiter', 'Stefan Gisler', 'Philipp Röllin'],
#  ['FDP-Fraktion'],
#  ['Martin B. Lehmann'],
#  ['SVP-Fraktion'],
#  ['SVP-Fraktion'],
#  ['SVP-Fraktion'],
#  ['CVP-Fraktion'],
#  ['Eric Frischknecht'],
#  ['Andreas Hürlimann', 'Erwina Winiger'],
#  ['Christina Huber'],
#  ['Karin Andenmatten', 'Martin Pfister', 'Albert C. Iten', 'Fredy Abächerli'],
#  ['Stephan Schleiss', 'Manuel Aeschbacher'],
#  ['Bettina Egler',
#   'Christina Bürgi Dellsperger',
#   'Hubert Schuler',
#   'Eusebius Spescha'],
#  ['Martin Stuber', 'Vroni Straub-Müller'],
#  ['Franz Hürlimann'],
#  ['Thomas Lötscher', 'Daniel Abt'],
#  ['Martin B. Lehmann'],
#  ['Alternativen Fraktion'],
#  ['Anna Lustenberger-Seitz', 'Bettina Egler'],
#  ['Martin B. Lehmann', 'Alois Gössi'],
#  ['SVP-Fraktion'],
#  ['Christina Huber', 'Margrit Landtwing', 'Erwina Winiger'],
#  ['Georg Helfenstein',
#   'Markus Scheidegger',
#   'Franz Peter Iten',
#   'Vreni Wicky'],
#  ['Erwina Winiger', 'Eric Frischknecht'],
#  ['Stephan Schleiss'],
#  ['Hubert Schuler'],
#  ['Felix Häcki'],
#  ['Christina Huber', 'Eusebius Spescha'],
#  ['Alternativen Fraktion'],
#  ['Thomas Rickenbacher'],
#  ['Felix Häcki'],
#  ['FDP-Fraktion und'],
#  ['Monika Barmet'],
#  ['Eusebius Spescha'],
#  ['Franz Peter Iten'],
#  ['Bettina Egler'],
#  ['SP- und'],
#  ['Andreas Hausheer'],
#  ['SVP-Fraktion'],
#  ['Andrea Hodel', 'Bruno Pezzatti'],
#  ['Alois Gössi'],
#  ['Eric Frischknecht'],
#  ['Alternativen Fraktion'],
#  ['CVP-Fraktion'],
#  ['CVP-Fraktion'],
#  ['Christina Huber'],
#  ['Andreas Huwyler'],
#  ['Eusebius Spescha', 'Christina Bürgi Dellsperger'],
#  ['SP-Fraktion'],
#  ['Thiemo Hächler', 'CVP', 'Daniel Abt', 'FDP,', 'Karl Nussbaumer', 'SVP'],
#  ['Alternativen Fraktion'],
#  ['Eric Frischknecht'],
#  ['Silvan Hotz', 'Irène Castell-Bachmann'],
#  ['Christina Bürgi Dellsperger',
#   'Eusebius Spescha',
#   'Markus Jans',
#   'Christina Huber',
#   'Alois Gössi'],
#  ['Anna Lustenberger-Seitz'],
#  ['Chrstina Huber', 'Christina Bürgi Dellsperger', 'Bettina Egler'],
#  ['Eusebius Spescha', 'Christina Bürgi Dellsperger', 'Markus Jans'],
#  ['Barbara Strub', 'Moritz Schmid', 'Monika Barmet'],
#  ['FDP-Fraktion'],
#  ['Thomas Lötscher'],
#  ['Christina Bürgi Dellsperger'],
#  ['Anna Lustenberger-Seitz'],
#  ['CVP-Fraktion'],
#  ['Werner Villiger', 'Rudolf Balsiger'],
#  ['Alternativen Fraktion'],
#  ['Eusebius Spescha'],
#  ['Andreas Hürlimann'],
#  ['CVP-Fraktion'],
#  ['CVP-Fraktion'],
#  ['Eric Frischknecht'],
#  ['CVP-Fraktion'],
#  ['SVP-Fraktion'],
#  ['Alois Gössi zur Ergänzung des Kantonsratsbeschlusses'],
#  ['Alois Gössi'],
#  ['Bettina Egler'],
#  ['SVP-Fraktion'],
#  ['Stephan Schleiss'],
#  ['Daniel Abt'],
#  ['Martin B. Lehmann'],
#  ['Martin B. Lehmann'],
#  ['SVP-Fraktion'],
#  ['Stephan Schleiss', 'Rudolf Balsiger'],
#  ['Rupan Sivaganesan',
#   'Rosemarie Fähndrich Burger',
#   'Eusebius Spescha',
#   'Vreni Wicky',
#   'Beatrice Gaier',
#   'Markus Jans'],
#  ['Beatrice Gaier', 'Monika Barmet'],
#  ['Eusebius Spescha', 'Markus Jans'],
#  ['SVP-Fraktion'],
#  ['Alois Gössi', 'Christina Bürgi Dellsperger'],
#  ['CVP-Fraktion'],
#  ['Stephan Schleiss'],
#  ['Markus Jans',
#   'Thomas Rickenbacher',
#   'Erwina Winiger',
#   'Andreas Hürlimann',
#   'Hubert Schuler',
#   'Hanni Schriber-Neiger'],
#  ['Hubert Schuler', 'Bettina Egler'],
#  ['FDP-Fraktion'],
#  ['Thomas Brändle'],
#  ['Alternativen Fraktion'],
#  ['Alois Gössi', 'Martin B. Lehmann'],
#  ['Alternativen Fraktion'],
#  ['Martin B. Lehmann'],
#  ['Alternativen Fraktion'],
#  ['Andreas Huwyler'],
#  ['Alois Gössi', 'Markus Jans'],
#  ['Silvan Hotz'],
#  ['Vreni Wicky'],
#  ['Franz Müller'],
#  ['Franz Müller'],
#  ['Hans Christen',
#   'Eusebius Spescha',
#   'Beat Stocker',
#   'Martin Stuber',
#   'Vreni Wicky'],
#  ['Thomas Lötscher'],
#  ['Berty Zeiter', 'Anna Lustenberger-Seitz'],
#  ['Eusebius Spescha'],
#  ['Franz Müller'],
#  ['Silvan Hotz'],
#  ['Alternativen Fraktion'],
#  ['Rudolf Balsiger'],
#  ['Daniel Burch'],
#  ['FDP-', 'CVP- und SVP-Fraktion'],
#  ['Thomas Lötscher'],
#  ['Franz Müller'],
#  ['Silvan Hotz'],
#  ['Franz Zoppi', 'Manuel Aeschbacher'],
#  ['Monika Barmet', 'Karl Künzle', 'Karl Nussbaumer', 'Bruno Pezzatti'],
#  ['CVP-Fraktion'],
#  ['René Bär'],
#  ['Max Uebelhart'],
#  ['René Bär'],
#  ['Stefan Gisler', 'Christian Siegwart'],
#  ['Martin Stuber'],
#  ['Thomas Brändle'],
#  ['Alternativen Fraktion'],
#  ['SP-Fraktion'],
#  ['Jean-Pierre Prodolliet', 'Rosemarie Fähndrich Burger'],
#  ['Kommission für Wasserbau und Gewässerschutz'],
#  ['Vreni Wicky'],
#  ['Anna Lustenberger-Seitz', 'Berty Zeiter', 'Martin Stuber'],
#  ['Baarer Kantonsrätinnen', 'Kantonsräten'],
#  ['Peter Rust'],
#  ['Thomas Lötscher'],
#  ['SVP-Fraktion'],
#  ['Rolf Schweiger'],
#  ['CVP-Fraktion'],
#  ['Karl Rust', 'Hans Peter Schlumpf', 'Werner Villiger', 'Othmar Birri'],
#  ['Alternativen Fraktion'],
#  ['Alternativen Fraktion'],
#  ['Alois Gössi', 'Leo Granziol', 'Stefan Gisler', 'Daniel Grunder'],
#  ['CVP-Fraktion'],
#  ['FDP-Fraktion'],
#  ['Martin Stuber'],
#  ['Rudolf Balsiger', 'Leo Granziol'],
#  ['Markus Jans'],
#  ['SP-Fraktion'],
#  ['Alternativen Fraktion'],
#  ['Louis Suter'],
#  ['SP-Fraktion'],
#  ['Leo Granziol', 'Andreas Huwyler'],
#  ...]

# %% [markdown]
# nameliste[1] range(0:1219)

# %%
len(nameliste)
# Out:
# 1220

# %%
lestlist=[]
lestlist.append("suppe")
len(lestlist)
# Out:
# 1

# %%
namenliste_n=[]
counter = 0
zaehler = 0

for alleeintraege in df_vs["Geschäft"]: #hier gehe ich jede Liste im Dataframe an.
    print(alleeintraege)
    name = alleeintraege[zaehler] #ich will sie auslesen und die Namen einzeln.

    if zaehler < len(alleeintraege)-1: #da die Listen unterschiedlich lang sind, versuche ich hier dies zu berücksichtigen
        zaehler=zaehler+1 #es scheint leider nicht zu funktionieren. 
    elif zaehler == (alleeintraege)-1: 
        continue
   
          
    
    minidictnamen={"Name":name}
    namenliste_n.append(minidictnamen)
# Out:
# ['Luzian Franzini', 'Esther Haas']
# ['Luzian Franzini', 'Rita Hofer', 'Tabea Zimmermann Gibson', 'Andreas Lustenberger', 'Hanni Schriber-Neiger']
# ['Fabio Iten', 'Laura Dittli', 'Anna Bieri']
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-62-275750a63d40> in <module>
#       9     if zaehler < len(alleeintraege)-1: #da die Listen unterschiedlich lang sind, versuche ich hier dies zu berücksichtigen
#      10         zaehler=zaehler+1 #es scheint leider nicht zu funktionieren
# ---> 11     elif zaehler == (alleeintraege)-1:
#      12         continue
#      13
#
# TypeError: unsupported operand type(s) for -: 'list' and 'int'

# %%
pd.DataFrame(namenliste_n)
# Out:
#               Name
# 0  Luzian Franzini
# 1       Rita Hofer
# 2       Anna Bieri

# %%
return tuple(namenliste_n)
# Out:
#   File "<ipython-input-30-9ceecdd1bfe4>", line 1
#     return tuple(namenliste_n)
#                               ^
# SyntaxError: 'return' outside function

# %%
#Ich versuche es mal schriftlich bevor ich den Loop schreibe:
liste=[]
namenliste={"sophie", "anna","julia"}
minidicttest={"ART": "Motion", "NUMMER": 23455, "NAMEN":namenliste}
liste.append(minidicttest)

# %%
df_test=pd.DataFrame(liste)

# %%
df_test

# %%
for key, value in minidict_g.items():
        if value == '':
            minidict_g[key] = 'NaN'  #hier schaue ich noch, dass ich die Leeren Zeilen mit NAN ersetzten kann.
        else:
            minidict_g[key] = value
