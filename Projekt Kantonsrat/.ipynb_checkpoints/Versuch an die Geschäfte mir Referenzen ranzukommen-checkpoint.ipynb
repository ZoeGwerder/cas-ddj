# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup
from datetime import datetime
import numpy as np
import requests, zipfile, io #zum abspeichern von PDFs
from tqdm import tqdm # Anzeigen des aktuellen Ladestandes
import PyPDF2
import re
from os import listdir
from os.path import isfile, join
import locale #für das deutsche Zeitformat

# %% [markdown]
# ## 1. URL von allen Hauptseiten holen

# %%
#alle urls und infos der Hauptseiten holen.
url = "https://kr-geschaefte.zug.ch/gast/geschaefte?commit=Filtern&geschaeft_filter%5Babgeschlossen_bis%5D=&geschaeft_filter%5Babgeschlossen_von%5D=&geschaeft_filter%5Barten_refs%5D%5B%5D=&geschaeft_filter%5Beingereicht_bis%5D=&geschaeft_filter%5Beingereicht_von%5D=&geschaeft_filter%5Bfrist_bis%5D=&geschaeft_filter%5Bhistorische_staende_refs%5D%5B%5D=&geschaeft_filter%5Bkommissionen_refs%5D%5B%5D=&geschaeft_filter%5Bstaende_refs%5D%5B%5D=&geschaeft_filter%5Bstatus_ids%5D%5B%5D=haengig&geschaeft_filter%5Bstatus_ids%5D%5B%5D=abgeschlossen&geschaeft_filter%5Bstatus_ids%5D%5B%5D=&geschaeft_filter%5Btitel%5D=&geschaeft_filter%5Bzustaendig_refs%5D%5B%5D=&page="

alle_seiten = []
for seite in range(1,41):
    r=requests.get(url+str(seite))
    soup = BeautifulSoup(r.text,"html.parser")
    
    tr_list=soup.find_all("tr")[2:] #erst ab der Position 2 sind die Daten relevant.
    
    for element in tr_list:
        td_list = element.find_all("td")
        vorlag_nr=td_list[0].text
        href = td_list[0].find("a")["href"]
        text = td_list[1].text
        stand = td_list[2].text
        zustaendig = td_list[3].text
        geschaeft_art = td_list[4].text
        status = td_list[5].text
        
        mini_dict = {"VorlageNR":vorlag_nr,"url":href,"Geschäft":text, "Stand":stand, "Zuständigkeit":zustaendig, "Art des Geschäfts": geschaeft_art, "Status":status}

        alle_seiten.append(mini_dict)

# %%
pd.DataFrame(alle_seiten)
df_a=pd.DataFrame(alle_seiten)
# Die Geschäftsnummer zur Zahl machen. 
df_a["VorlageNR"] = df_a["VorlageNR"].astype(int)

# %% [markdown]
# ## 1.1 Selektion: Fokus auf Vorstösse
# So will ich eine allzu grosse pdf-Schwemme verhindern.
# Die Idee: nur jene Geschäfte auf den PC ziehen, die auch relevant sind für die Auswertung.
# Also nur Vorstösse. Mich so bis zu den PDF's vorkämpfen, um auch hier nur jene auf meinem Rechner zu haben,
# die ich wirklich auf meinem Rechner will.

# %%
#hier mache ich eine Liste, die nur aus denjenigen URLs besteht, die Vorstösse sind. 

list_of_vorstoss=["Motion","Interpellation","Postulat","Kleine Anfrage", "Initiative"]
df_v=df_a[df_a["Art des Geschäfts"].isin (list_of_vorstoss)]

# %%
df_v #hier habe ich nun alle Vorstösse

# %%
df_v=df_v.reset_index()#Ich will überall nun denselben Index. deshalb nur soviel, wie ich Zeilen habe
df_v.bto_csv("KRFrames/df_v_Hauptseiten")

# %%
df_v=pd.read_csv("KRFrames/df_v_Hauptseiten")

# %%
df_v
# Out:
#       Unnamed: 0  index  VorlageNR                    url  \
# 0              0      0       3020  /gast/geschaefte/2008
# 1              1      1       3019  /gast/geschaefte/2007
# 2              2      2       3018  /gast/geschaefte/2006
# 3              3      3       3017  /gast/geschaefte/2005
# 4              4      6       3014  /gast/geschaefte/2002
# ...          ...    ...        ...                    ...
# 1215        1215   1946        762  /gast/geschaefte/1331
# 1216        1216   1952        666  /gast/geschaefte/1325
# 1217        1217   1968        304  /gast/geschaefte/1309
# 1218        1218   1969        282  /gast/geschaefte/1712
# 1219        1219   1972         81  /gast/geschaefte/1334
#
#                                                Geschäft  \
# 0     Postulat von Luzian Franzini und Esther Haas b...
# 1     Motion von Luzian Franzini, Rita Hofer, Tabea ...
# 2     Interpellation von Fabio Iten, Laura Dittli un...
# 3     Postulat von Tabea Zimmermann Gibson, Stéphani...
# 4     Interpellation der SVP-Fraktion betreffend mob...
# ...                                                 ...
# 1215  Motion der erweiterten Justizprüfungskommissio...
# 1216  Motion der Kommission Teilrevision Personalges...
# 1217  Motion von Manuela Weichelt betreffend HIV-Prä...
# 1218  Motion von Christoph Hohler betreffend Radstre...
# 1219  Motion der vorberatenden Kommission betreffend...
#
#                              Stand              Zuständigkeit  \
# 0     Überweisung an Regierungsrat       Sicherheitsdirektion
# 1     Überweisung an Regierungsrat       Direktion des Innern
# 2     Überweisung an Regierungsrat  Volkswirtschaftsdirektion
# 3     Überweisung an Regierungsrat       Direktion des Innern
# 4                    Kenntnisnahme       Sicherheitsdirektion
# ...                            ...                        ...
# 1215                Datenmigration                        NaN
# 1216                Datenmigration                        NaN
# 1217                Datenmigration                        NaN
# 1218               Frist erstreckt               Baudirektion
# 1219                Datenmigration                        NaN
#
#      Art des Geschäfts         Status
# 0             Postulat         hängig
# 1               Motion         hängig
# 2       Interpellation         hängig
# 3             Postulat         hängig
# 4       Interpellation         hängig
# ...                ...            ...
# 1215            Motion  abgeschlossen
# 1216            Motion  abgeschlossen
# 1217            Motion  abgeschlossen
# 1218            Motion         hängig
# 1219            Motion  abgeschlossen
#
# [1220 rows x 9 columns]

# %% [markdown]
# ### 1.1.1 Eine Liste aus allen Geschäfts-URLs machen (um später auf diese zuzugreiffen)

# %%
url_liste_ganz=[]
url_anfang_original="https://kr-geschaefte.zug.ch"
for element in df_v["url"]:
    url_liste_ganz.append(url_anfang_original+element)
#diese werden zusammengefügt aus dem Anfang der Adresse sowie dem Geschäfts-URL

# %%
len(url_liste_ganz)

# %% [markdown]
# ### Die einzelnen Geschäfte aufrufen und Infos rausholen

# %% [markdown]
# # -> Einschub: ich will speichern und mit diesen Daten dann arbeiten.

# %%
#habe nun alle Seiten der Geschäfte auf meinem Rechner gespeichert. 
number = 0
for page in url_liste_ganz:
    page_content = requests.get(page)
    page_content = page_content.text
    with open("Geschaeft"+str(number)+".html", "w") as file:
        file.write(page_content)
        file.close()
    number +=1
    #Es sind nun exakt so viele Seiten auf meinem Rechner, wie das DataFrame oben Zeilen anzeigt

# %% [markdown]
# # <-Einschub-Ende. Ich habe es geschafft, das zu speichern.

# %%
#nun muss ich den Code ändern, sodass ich nicht mehr online zugreiffe sondern über meinen Ordner.
#hier nun die Liste der Zugriffe.
geschaefts_liste=[]#####ACHTUNG ich mache den RANGE kleiner, um weniger GEschäfte zu erhalten.

for seite_g in range(0,1220): #Range für alle Geschäfte wäre 1219!
    gesch= "KRhtml/Geschaeft"+str(seite_g)+".html"
    geschaefts_liste.append(gesch)

# %%
len(geschaefts_liste)
# Out:
# 1220

# %%
geschaefts_liste[-10:]
# Out:
# ['KRhtml/Geschaeft1210.html',
#  'KRhtml/Geschaeft1211.html',
#  'KRhtml/Geschaeft1212.html',
#  'KRhtml/Geschaeft1213.html',
#  'KRhtml/Geschaeft1214.html',
#  'KRhtml/Geschaeft1215.html',
#  'KRhtml/Geschaeft1216.html',
#  'KRhtml/Geschaeft1217.html',
#  'KRhtml/Geschaeft1218.html',
#  'KRhtml/Geschaeft1219.html']

# %%
df_g=pd.DataFrame(eingang_list)

# %%
df_g.to_csv("KRFrames/df_g_LinkszuPDF")

# %%
df_g=pd.read_csv("KRFrames/df_g_LinkszuPDF")

# %%
df_g
# Out:
#       Unnamed: 0  VorlageNR Einreichedatum  \
# 0              0       3020     2019-10-11
# 1              1       3019     2019-10-11
# 2              2       3018     2019-10-07
# 3              3       3017     2019-10-06
# 4              4       3014     2019-09-26
# ...          ...        ...            ...
# 1215        1215        762            NaN
# 1216        1216        666            NaN
# 1217        1217        304            NaN
# 1218        1218       2635     1995-08-07
# 1219        1219         81            NaN
#
#                                       Link Vorstoss-PDF
# 0     /dokumente/8316/3020-1-16168_Racial-Profiling.pdf
# 1     /dokumente/8317/3019-1-16167_Chancengleichheit...
# 2            /dokumente/8310/3018-1-16166_Praktikum.pdf
# 3     /dokumente/8311/3017-1-16165_Frauenwahl-stimmr...
# 4     /dokumente/8312/3014-1-16159_Geschwindigkeitsk...
# ...                                                 ...
# 1215                    /dokumente/4232/pdoc_1047_1.pdf
# 1216                      /dokumente/4215/pdoc_55_1.pdf
# 1217                      /dokumente/4179/pdoc_50_1.pdf
# 1218                              /gast/geschaefte/1620
# 1219                    /dokumente/4236/pdoc_1705_1.pdf
#
# [1220 rows x 4 columns]

# %%
#Ich suche nun alle raus, die einen Referenz haben, vielleicht geben die mehr aufschluss auf 
# Wahlvorschläge 
df_ref=df_g[df_g["Link Vorstoss-PDF"].str.contains("gast")]

# %%
df_rf=df_ref.rename(columns={"Link Vorstoss-PDF":"url mir Referenz"})

# %%
url_liste_ganz=[]
url_anfang_original="https://kr-geschaefte.zug.ch"
for element in df_rf["url mir Referenz"]:
    url_liste_ganz.append(url_anfang_original+element)
#diese werden zusammengefügt aus dem Anfang der Adresse sowie dem Geschäfts-URL

# %%
number = 0
for page in url_liste_ganz:
    page_content = requests.get(page)
    page_content = page_content.text
    with open("KRRef/Geschaeft"+str(number)+".html", "w") as file:
        file.write(page_content)
        file.close()
    number +=1

# %%
geschaefts_liste=[]#####ACHTUNG ich mache den RANGE kleiner, um weniger GEschäfte zu erhalten.

for seite_g in range(0,1220): #Range für alle Geschäfte wäre 1219!
    gesch= "KRRef/Geschaeft"+str(seite_g)+".html"
    geschaefts_liste.append(gesch)

# %%
# Die fehlerhaften Geschäfte weil sie REfernzen haben abrufen und den PDF-LInk holen
eingang_list=[]


for geschaeft in df_ref["url mir Referenz"]:
    file = open(KRgeschaeft, 'r')
    text = file.read()
    soup_g = BeautifulSoup(text, 'html.parser')
    tr_g_list=soup_g.find_all("tr")
    td_g_list=tr_g_list[-1].find_all("td")#hier gehe ich zum Dokument.
    gesch_nr = tr_g_list[-1].find_all("td")[0].text
    einger_am = tr_g_list[1].find_all("td")[0].text   
   
   
     #Da es zum Teil Referenzen hat und dadurch ein anderer Ort abgegriffen werden muss, muss ich varieren.
    
    if td_g_list[-1].find_all("a")[0].text== "1": #Ich brauche immer das Dokument 1. 
        url_v_pdf = td_g_list[-1].find("a")["href"]
    
    elif td_g_list[-1].find_all("a")[0].text== "2": #bei älteren GEschäften sind es Bericht&Anträge
        url_v_pdf = td_g_list[-1].find("a")["href"]   
    else: 
        td_g_list[-1].find_all("a")[0].text== "3"
        url_v_pdf = td_g_list[-1].find("a")["href"]
   
            
    
    minidict_g={"VorlageNR":gesch_nr, "Einreichedatum":einger_am, "Link Vorstoss-PDF":url_v_pdf,}
    for key, value in minidict_g.items():
        if value == '':
            minidict_g[key] = 'NaN'  #hier schaue ich noch, dass ich die Leeren Zeilen mit NAN ersetzten kann.
        else:
            minidict_g[key] = value
            
    eingang_list.append(minidict_g)

# %%
# Nun zusammenbringen mit dem URL
df_referenzen=pd.merge(df_v,df_ref, on="VorlageNR", how="inner")

# %%
df_referenzen
# Out:
#     Unnamed: 0_x  index  VorlageNR                    url  \
# 0             19     27       2993  /gast/geschaefte/1981
# 1             84    139       2881  /gast/geschaefte/1869
# 2             87    143       2877  /gast/geschaefte/1865
# 3             88    144       2876  /gast/geschaefte/1864
# 4            115    184       2834  /gast/geschaefte/1824
# 5            118    187       2831  /gast/geschaefte/1821
# 6            135    210       2808  /gast/geschaefte/1798
# 7            147    226       2792  /gast/geschaefte/1782
# 8            154    236       2782  /gast/geschaefte/1772
# 9            155    237       2781  /gast/geschaefte/1771
# 10           159    243       2774  /gast/geschaefte/1764
# 11           160    244       2773  /gast/geschaefte/1763
# 12           201    299       2718  /gast/geschaefte/1707
# 13           201    299       2718  /gast/geschaefte/1707
# 14           327    488       2526  /gast/geschaefte/1512
# 15           338    505       2509  /gast/geschaefte/1495
# 16           361    537       2477  /gast/geschaefte/1465
# 17           379    561       2453  /gast/geschaefte/1437
# 18           381    565       2448  /gast/geschaefte/1433
# 19           382    566       2447  /gast/geschaefte/1435
# 20           413    603       2407  /gast/geschaefte/1388
# 21           422    616       2391  /gast/geschaefte/1381
# 22           432    629       2372   /gast/geschaefte/622
# 23           434    631       2370   /gast/geschaefte/627
# 24           435    632       2369   /gast/geschaefte/620
# 25           457    659       2342   /gast/geschaefte/581
# 26           457    659       2342   /gast/geschaefte/581
# 27           457    659       2342   /gast/geschaefte/581
# 28           483    698       2303   /gast/geschaefte/547
# 29           490    707       2294   /gast/geschaefte/548
# 30           523    758       2243   /gast/geschaefte/494
# 31           523    758       2243   /gast/geschaefte/494
# 32           523    758       2243   /gast/geschaefte/494
# 33           579    859       2141   /gast/geschaefte/393
# 34           589    871       2129   /gast/geschaefte/381
# 35           589    871       2129   /gast/geschaefte/381
# 36           589    871       2129   /gast/geschaefte/381
# 37           589    871       2129   /gast/geschaefte/381
# 38           589    871       2129   /gast/geschaefte/381
# 39           589    871       2129   /gast/geschaefte/381
# 40           638    968       2028   /gast/geschaefte/283
# 41           692   1065       1923   /gast/geschaefte/184
# 42           693   1066       1922   /gast/geschaefte/183
# 43           704   1087       1899   /gast/geschaefte/160
# 44           704   1087       1899   /gast/geschaefte/160
# 45           759   1177       1804    /gast/geschaefte/82
# 46           759   1177       1804    /gast/geschaefte/82
# 47           842   1293       1683    /gast/geschaefte/18
# 48           842   1293       1683    /gast/geschaefte/18
# 49           842   1293       1683    /gast/geschaefte/18
# 50           844   1295       1681  /gast/geschaefte/1241
# 51          1006   1577       1380   /gast/geschaefte/970
#
#                                              Geschäft  \
# 0   Motion von Anna Bieri und Barbara Häseli betre...
# 1   Postulat von Anna Bieri und Barbara Häseli bet...
# 2   Interpellation der Fraktion Alternative - die ...
# 3   Interpellation von Andreas Lustenberger betref...
# 4   Postulat von Gabriela Ingold, Beat Iten, Peter...
# 5   Postulat von Laura Dittli, Patrick Iten und Ir...
# 6   Postulat von Beni Riedi, Florian Weber und Pir...
# 7   Kleine Anfrage von Beni Riedi, Florian Weber u...
# 8   Postulat von Thomas Werner betreffend Bushalte...
# 9   Motion von Thomas Werner betreffend Anpassung ...
# 10  Interpellation der SVP-Fraktion betreffend Ung...
# 11  Kleine Anfrage der SVP-Fraktion betreffend Wer...
# 12  Interpellation der Fraktion Alternative - die ...
# 13  Interpellation der Fraktion Alternative - die ...
# 14  Motion von Anna Bieri und Laura Dittli betreff...
# 15  Motion von Laura Dittli betreffend Einführung ...
# 16  Motion von Thomas Lötscher betreffend die Scha...
# 17  Motion von Thiemo Hächler, Daniel Abt und Manu...
# 18  Interpellation der Stadtzuger Kantonsrätinnen ...
# 19  Postulat der Stadtzuger Kantonsrätinnen und Ka...
# 20  Motion der ad-hoc Kommission zur Untersuchung ...
# 21  Motion der CVP-Fraktion betreffend Infrastrukt...
# 22  Interpellation von Daniel Stadlin betreffend k...
# 23  Motion der SVP-Fraktion betreffend Vereinfachu...
# 24  Interpellation der Alternativen Grünen Fraktio...
# 25  Motion von Thiemo Hächler, Daniel Abt und Manu...
# 26  Motion von Thiemo Hächler, Daniel Abt und Manu...
# 27  Motion von Thiemo Hächler, Daniel Abt und Manu...
# 28  Motion der Staatswirtschaftskommission betreff...
# 29  Postulat der SVP-Fraktion betreffend 45 Ämter ...
# 30  Motion der vorberatenden Kommission zum Pensio...
# 31  Motion der vorberatenden Kommission zum Pensio...
# 32  Motion der vorberatenden Kommission zum Pensio...
# 33  Motion von Daniel Stadlin betreffend Anpassung...
# 34  Motion von Philippe Camenisch, Cornelia Stocke...
# 35  Motion von Philippe Camenisch, Cornelia Stocke...
# 36  Motion von Philippe Camenisch, Cornelia Stocke...
# 37  Motion von Philippe Camenisch, Cornelia Stocke...
# 38  Motion von Philippe Camenisch, Cornelia Stocke...
# 39  Motion von Philippe Camenisch, Cornelia Stocke...
# 40  Interpellation von Anna Bieri und Frowin Betsc...
# 41  Motion erw. JPK. Erarbeitung gesetzlicher Grun...
# 42  Postulat der erweiterten Jusitzprüfungskommiss...
# 43  Motion von Martin Stuber, Heini Schmid und Tho...
# 44  Motion von Martin Stuber, Heini Schmid und Tho...
# 45  Motion und Postulat der FDP-Fraktion zum Ausba...
# 46  Motion und Postulat der FDP-Fraktion zum Ausba...
# 47  Motion der CVP-Fraktion betreffend Auftrag an ...
# 48  Motion der CVP-Fraktion betreffend Auftrag an ...
# 49  Motion der CVP-Fraktion betreffend Auftrag an ...
# 50  Motion der CVP-Fraktion betreffend Einführung ...
# 51  Interpellation der Alternativen Fraktion betre...
#
#                          Stand                     Zuständigkeit  \
# 0           Erheblicherklärung              Gesundheitsdirektion
# 1     Nicht-Erheblicherklärung              Gesundheitsdirektion
# 2                Kenntnisnahme         Volkswirtschaftsdirektion
# 3                Kenntnisnahme         Volkswirtschaftsdirektion
# 4            Erledigterklärung         Volkswirtschaftsdirektion
# 5     Nicht-Erheblicherklärung         Volkswirtschaftsdirektion
# 6     Nicht-Erheblicherklärung              Sicherheitsdirektion
# 7   Antwort des Regierungsrats              Sicherheitsdirektion
# 8     Nicht-Erheblicherklärung                      Baudirektion
# 9     Nicht-Erheblicherklärung                      Baudirektion
# 10               Kenntnisnahme              Sicherheitsdirektion
# 11  Antwort des Regierungsrats              Sicherheitsdirektion
# 12               Kenntnisnahme         Volkswirtschaftsdirektion
# 13               Kenntnisnahme         Volkswirtschaftsdirektion
# 14           Erledigterklärung  Direktion für Bildung und Kultur
# 15           Erledigterklärung              Direktion des Innern
# 16           Erledigterklärung              Direktion des Innern
# 17           Erledigterklärung              Direktion des Innern
# 18               Kenntnisnahme         Volkswirtschaftsdirektion
# 19           Erledigterklärung         Volkswirtschaftsdirektion
# 20           Erledigterklärung                   Finanzdirektion
# 21           Erledigterklärung                   Finanzdirektion
# 22               Kenntnisnahme                   Finanzdirektion
# 23    Nicht-Erheblicherklärung         Volkswirtschaftsdirektion
# 24               Kenntnisnahme         Volkswirtschaftsdirektion
# 25           Erledigterklärung              Direktion des Innern
# 26           Erledigterklärung              Direktion des Innern
# 27           Erledigterklärung              Direktion des Innern
# 28           Erledigterklärung                   Finanzdirektion
# 29          Erheblicherklärung                     Staatskanzlei
# 30           Erledigterklärung                   Finanzdirektion
# 31           Erledigterklärung                   Finanzdirektion
# 32           Erledigterklärung                   Finanzdirektion
# 33    Nicht-Erheblicherklärung                   Finanzdirektion
# 34    Nicht-Erheblicherklärung                   Finanzdirektion
# 35    Nicht-Erheblicherklärung                   Finanzdirektion
# 36    Nicht-Erheblicherklärung                   Finanzdirektion
# 37    Nicht-Erheblicherklärung                   Finanzdirektion
# 38    Nicht-Erheblicherklärung                   Finanzdirektion
# 39    Nicht-Erheblicherklärung                   Finanzdirektion
# 40              Datenmigration                               NaN
# 41           Erledigterklärung                   Finanzdirektion
# 42           Erledigterklärung                   Finanzdirektion
# 43           Erledigterklärung         Volkswirtschaftsdirektion
# 44           Erledigterklärung         Volkswirtschaftsdirektion
# 45           Erledigterklärung         Volkswirtschaftsdirektion
# 46           Erledigterklärung         Volkswirtschaftsdirektion
# 47           Erledigterklärung              Sicherheitsdirektion
# 48           Erledigterklärung              Sicherheitsdirektion
# 49           Erledigterklärung              Sicherheitsdirektion
# 50           Erledigterklärung                   Finanzdirektion
# 51               Kenntnisnahme                               NaN
#
#    Art des Geschäfts         Status  Unnamed: 0_y Einreichedatum  \
# 0             Motion         hängig            84     2018-06-14
# 1           Postulat  abgeschlossen            19     2019-07-04
# 2     Interpellation  abgeschlossen            88     2018-05-17
# 3     Interpellation  abgeschlossen            87     2018-05-18
# 4           Postulat  abgeschlossen           118     2018-02-07
# 5           Postulat  abgeschlossen           115     2018-02-13
# 6           Postulat  abgeschlossen           147     2017-10-10
# 7     Kleine Anfrage  abgeschlossen           135     2017-12-02
# 8           Postulat  abgeschlossen           155     2017-09-11
# 9             Motion  abgeschlossen           154     2017-09-11
# 10    Interpellation  abgeschlossen           160     2017-08-15
# 11    Kleine Anfrage  abgeschlossen           159     2017-08-15
# 12    Interpellation  abgeschlossen           576            NaN
# 13    Interpellation  abgeschlossen          1006            NaN
# 14            Motion  abgeschlossen           638            NaN
# 15            Motion  abgeschlossen           361     2015-01-29
# 16            Motion  abgeschlossen           338     2015-05-11
# 17            Motion  abgeschlossen           457     2014-01-13
# 18    Interpellation  abgeschlossen           382     2014-11-13
# 19          Postulat  abgeschlossen           381     2014-11-13
# 20            Motion  abgeschlossen           351     2015-03-10
# 21            Motion  abgeschlossen           432     2014-03-09
# 22    Interpellation  abgeschlossen           422     2014-04-25
# 23            Motion  abgeschlossen           435     2014-03-04
# 24    Interpellation  abgeschlossen           434     2014-03-25
# 25            Motion  abgeschlossen           333     2015-05-28
# 26            Motion  abgeschlossen           334     2015-05-28
# 27            Motion  abgeschlossen           379     2014-11-25
# 28            Motion  abgeschlossen           523     2013-04-16
# 29          Postulat         hängig           288     2016-02-08
# 30            Motion  abgeschlossen           430     2014-03-10
# 31            Motion  abgeschlossen           431     2014-03-10
# 32            Motion  abgeschlossen           483     2013-10-07
# 33            Motion  abgeschlossen           589     2012-03-29
# 34            Motion  abgeschlossen           330     2015-06-09
# 35            Motion  abgeschlossen           336     2015-05-27
# 36            Motion  abgeschlossen           340     2015-05-01
# 37            Motion  abgeschlossen           446     2014-02-02
# 38            Motion  abgeschlossen           513     2013-05-06
# 39            Motion  abgeschlossen           579     2013-12-17
# 40    Interpellation  abgeschlossen           327     2015-06-14
# 41            Motion  abgeschlossen           844     2008-05-25
# 42          Postulat  abgeschlossen           842            NaN
# 43            Motion  abgeschlossen           415     2014-06-04
# 44            Motion  abgeschlossen           759     2009-03-30
# 45            Motion  abgeschlossen           274     2016-04-14
# 46            Motion  abgeschlossen           704     2010-01-28
# 47            Motion  abgeschlossen           690     2009-07-02
# 48            Motion  abgeschlossen           691     2009-07-02
# 49            Motion  abgeschlossen           693     2009-07-02
# 50            Motion  abgeschlossen           692     2009-07-02
# 51    Interpellation  abgeschlossen           201     2017-02-26
#
#         Link Vorstoss-PDF
# 0   /gast/geschaefte/1981
# 1   /gast/geschaefte/1869
# 2   /gast/geschaefte/1865
# 3   /gast/geschaefte/1864
# 4   /gast/geschaefte/1824
# 5   /gast/geschaefte/1821
# 6   /gast/geschaefte/1798
# 7   /gast/geschaefte/1782
# 8   /gast/geschaefte/1772
# 9   /gast/geschaefte/1771
# 10  /gast/geschaefte/1764
# 11  /gast/geschaefte/1763
# 12  /gast/geschaefte/1707
# 13  /gast/geschaefte/1707
# 14  /gast/geschaefte/1512
# 15  /gast/geschaefte/1495
# 16  /gast/geschaefte/1465
# 17  /gast/geschaefte/1437
# 18  /gast/geschaefte/1433
# 19  /gast/geschaefte/1435
# 20  /gast/geschaefte/1388
# 21  /gast/geschaefte/1381
# 22   /gast/geschaefte/622
# 23   /gast/geschaefte/627
# 24   /gast/geschaefte/620
# 25   /gast/geschaefte/581
# 26   /gast/geschaefte/581
# 27   /gast/geschaefte/581
# 28   /gast/geschaefte/547
# 29   /gast/geschaefte/548
# 30   /gast/geschaefte/494
# 31   /gast/geschaefte/494
# 32   /gast/geschaefte/494
# 33   /gast/geschaefte/393
# 34   /gast/geschaefte/381
# 35   /gast/geschaefte/381
# 36   /gast/geschaefte/381
# 37   /gast/geschaefte/381
# 38   /gast/geschaefte/381
# 39   /gast/geschaefte/381
# 40   /gast/geschaefte/283
# 41   /gast/geschaefte/184
# 42   /gast/geschaefte/183
# 43   /gast/geschaefte/160
# 44   /gast/geschaefte/160
# 45    /gast/geschaefte/82
# 46    /gast/geschaefte/82
# 47    /gast/geschaefte/18
# 48    /gast/geschaefte/18
# 49    /gast/geschaefte/18
# 50  /gast/geschaefte/1241
# 51   /gast/geschaefte/970

# %% [markdown]
# # 3. Die PDFs verlorenen Vorstösse runterladen

# %%
###FALSCH ich muss ja die Links erst noch finden!!!

# %%
for link in tqdm(df_referenzen["Link Vorstoss-PDF"]):
    r = requests.get("https://kr-geschaefte.zug.ch"+link, stream =True) #Das Stream braucht es, um mit dem Zip umgehen zu koennen
    name = link.split("/")[-1] #Der Computer kann mit "/" in einem Namen nicht umgehen, deshalb nehme ich die hier raus, und nehme nur den letzten Teil des NAmens.
    with open("KRGeschPDF/"+"REF"+name, "wb") as f:
        f.write(r.content)
# Out:
# 100%|██████████| 52/52 [00:09<00:00,  5.47it/s]

# %% [markdown]
# # 4. PDFs sind auf dem Rechner, nun lesbar machen und !Regex Baby!

# %%
#nun will ich aus jedem PDF zum Einen die VorlagenNR rausziehen sowie Namen und Datum hier die Definition
# ! Danke dem |$ am Schluss gibt es keinen Index-Error, wenn er kein Resultat findet.
regex_vorlage= r"VORLAGE.NR\..(\d*)\.1|$" #hier ziehe ich die Vorlagennummer raus. 
regex_datum = r"VOM.(\d+\..\w*.\d{4})|$" # hier gehe ich an das DAtum
regex_name=r"\bVON(.*UND.*)" #Hier muss ich noch überlegen, wie anders. Problem: zum Teil sind Namen einzeln zum teil mehr
# Und irgendwie erkennt er die Zeilenende nicht.
regex_name1= r"\bVON.(\w*.\w*\b)"
regex_partei= r"DER.(\w*)"

# %%
#Lösung online gefunden um aus dem PDF-Ordner eine Liste mit den Links herzustellen.
pdf_files_list= [f for f in listdir("KRGeschPDF") if isfile(join("KRGeschPDF", f))]

# %%
len(pdf_files_list) #Ich habe ja die PDFs ignoriert, zu welchen ich auf Grund der Referenz keine PDF-Links hatte.

# %%
# !!!!!! ACHTUNG: zuerst mit einzelen testen. Möglicherweise findet er die Files nicht. 
dat_pdf_list=[]
for dok in pdf_files_list:
    mypdf = open("KRGeschPDF/"+dok, mode='rb')
    pdf_name = dok
    pdf_document = PyPDF2.PdfFileReader(mypdf)
    first_page = pdf_document.getPage(0)
    front=first_page.extractText()
    dat_p_ein= re.findall(regex_datum, front, re.IGNORECASE)[0] #Ich greiffe auf das Datum zu
        # um zu verhindern, dass ich mehrer Daten und Vorlagen habe, sage ich mit [0] er soll das erste nehmen
    vorl_p_nr= re.findall(regex_vorlage, front, re.IGNORECASE)[0] # Ich greiffe auf die Vorlagennummer zu (zum Zusammenfügen der Dataframes)
    
    
    minidict_pdf_dat={"Einreichedatum": dat_p_ein, "VorlageNR":vorl_p_nr, "Filename":pdf_name}
    
    dat_pdf_list.append(minidict_pdf_dat)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-18-d9b123ec21b8> in <module>
#      10         # um zu verhindern, dass ich mehrer Daten und Vorlagen habe, sage ich mit [0] er soll das erste nehmen
#      11     vorl_p_nr= re.findall(regex_vorlage, front, re.IGNORECASE)[0] # Ich greiffe auf die Vorlagennummer zu (zum Zusammenfügen der Dataframes)
# ---> 12     bunda = re.findall(regex_bunda, front, re.IGNORECASE)[0]
#      13
#      14     minidict_pdf_dat={"Einreichedatum": dat_p_ein, "VorlageNR":vorl_p_nr, "Filename":pdf_name}
#
# IndexError: list index out of range

# %%
df_p=pd.DataFrame(dat_pdf_list)

# %%
df_p.sort_values("Einreichedatum") #Stichproben haben gezeigt, dass die fehlerhaften Datumsangaben in GEschäftern sind,
# Welche selber meist schon ein Datum haben.

# %%
df_p.to_csv("KRFrames/INFOSausPDF")

# %%
df_p["Filename"]

# %%
df_p=pd.read_csv("KRFrames/INFOSausPDF")
df_p
# Out:
#       Unnamed: 0      Einreichedatum  VorlageNR        Filename
# 943          943       27. März 2003     1109.0  pdoc_377_1.pdf
# 944          944      14. APRIL 2003     1110.0  pdoc_379_1.pdf
# 945          945         1. MAI 2003     1115.0  pdoc_392_1.pdf
# 946          946      28. APRIL 2003     1116.0  pdoc_394_1.pdf
# 947          947         8. MAI 2003     1118.0  pdoc_404_1.pdf
# ...          ...                 ...        ...             ...
# 1088        1088      4. AUGUST 2005     1362.0  pdoc_972_1.pdf
# 1089        1089     12. AUGUST 2005     1363.0  pdoc_977_1.pdf
# 1090        1090       23. JUNI 2005     1364.0  pdoc_978_1.pdf
# 1091        1091     26. AUGUST 2005     1365.0  pdoc_984_1.pdf
# 1092        1092  16. SEPTEMBER 2005     1374.0  pdoc_994_1.pdf
#
# [150 rows x 4 columns]

# %% [markdown]
# ## 4.1 Zeit in Datetime umwandeln
# schwierigkeit: wie bringe ich das deutsche Zeitformat in englisches. Mache ich es falsch oder gibts wieder probleme mit den Grossbuchstaben der Zeitformate? Hatten wir windowsuser auch schon.

# %%
df_p=pd.read_csv("KRFrames/INFOSausPDF")

# %%
locale.setlocale(locale.LC_ALL, 'de_DE') # hier die Sprachwahl
df_p["Einreichedatum"] = pd.to_datetime(df_p["Einreichedatum"], format= "%d. %B %Y", errors='coerce') #Angabe des Formats

# %%
 df_p #Halleluia:-) habs doch noch geschafft. Und die wenigen, die falsch formiert sind, werden nicht auffallen.

# %%
df_p.to_csv("KRFrames/KonvertierteDatenformate")

# %%
df_p=pd.read_csv("KRFrames/KonvertierteDatenformate")

# %%
#Nun noch ohne.0 hinten bei der VorlageNR. Ah es ist ein Float. Kann es also zu int oder str machen
df_p["VorlageNR"]=df_p["VorlageNR"].astype(str)

# %%
def splitting(elem):
    elem = elem.split('.')[0].strip()
    return elem

# %%
df_p["VorlageNR"]=df_p["VorlageNR"].apply(splitting) # So, nun sind die .0 weg. Mal schauen. Das String-Format reicht wohl
del df_p["Unnamed: 0"] # die beiden Spalten entfernen
del df_p["Unnamed: 0.1"]
df_ps=df_p.rename(columns={"Filename": "Link Vorstoss-PDF"}) #Spalte gleich benennen wie im anderen Frame

# %%
df_ps.to_csv("KRFrames/df_p_Datum") # und speichern

# %% [markdown]
# ## 4.2 Ein Dataframe machen, mit den PDF-Dokumentennamen
# - splitting funktion schreiben
# - auf Spalte anwenden
# - neu abspeichern

# %%
def splittpdf(elem):
    elem = elem.split('/')[-1].strip()
    return elem

# %%
df_g["Link Vorstoss-PDF"]=df_g["Link Vorstoss-PDF"].apply(splittpdf)

# %%
df_g.to_csv("KRFrames/df_g_Datum_mit_PDF")

# %% [markdown]
# ## 4.3 Nun zusammenfügen der beiden Daten-Dataframes anhand der PDF-Namen

# %%
df_g1=pd.read_csv("KRFrames/df_g_Datum_mit_PDF")
df_p1=pd.read_csv("KRFrames/df_p_Datum")

# %%
# Out:
#       Unnamed: 0 Einreichedatum  VorlageNR                Link Vorstoss-PDF
# 0              0     2007-09-17     1584.0          12487_1584.1_motion.pdf
# 1              1     2007-09-18     1589.0          12493_1589_1_motion.pdf
# 2              2     2007-12-06     1616.0          12562_1616_1_motion.pdf
# 3              3     2008-01-31     1635.0           12611_1635_1motion.pdf
# 4              4     2008-02-21     1644.0  12634_1644_1_interpellation.pdf
# ...          ...            ...        ...                              ...
# 1088        1088     2005-08-04     1362.0                   pdoc_972_1.pdf
# 1089        1089     2005-08-12     1363.0                   pdoc_977_1.pdf
# 1090        1090     2005-06-23     1364.0                   pdoc_978_1.pdf
# 1091        1091     2005-08-26     1365.0                   pdoc_984_1.pdf
# 1092        1092     2005-09-16     1374.0                   pdoc_994_1.pdf
#
# [1093 rows x 4 columns]

# %%
df_dat_max=pd.merge(df_g1, df_p1, how="left",on= "Link Vorstoss-PDF")

# %%
df_dat_max.shape
# Out:
# (1220, 8)

# %%
df_dat_max.sort_values("Einreichedatum_x").tail(100)  #So, jetzt sind zwar beide zusammen, aber noch nicht vereint
#Jetzt noch irgendwie die beiden Einreichedaten miteinander ableichen/ergängen.
# Out:
#       Unnamed: 0_x  Unnamed: 0.1  VorlageNR_x Einreichedatum_x  \
# 1119          1119          1119         1166              NaN
# 1120          1120          1120         1165              NaN
# 1121          1121          1121         1164              NaN
# 1122          1122          1122         1159              NaN
# 1123          1123          1123         1158              NaN
# ...            ...           ...          ...              ...
# 1214          1214          1214          801              NaN
# 1215          1215          1215          762              NaN
# 1216          1216          1216          666              NaN
# 1217          1217          1217          304              NaN
# 1219          1219          1219           81              NaN
#
#      Link Vorstoss-PDF  Unnamed: 0_y Einreichedatum_y  VorlageNR_y
# 1119    pdoc_526_1.pdf         976.0       2003-09-08       1166.0
# 1120    pdoc_525_1.pdf         975.0       2003-09-08       1165.0
# 1121    pdoc_524_1.pdf         974.0       2003-09-08       1164.0
# 1122    pdoc_498_1.pdf         972.0       2003-09-01       1159.0
# 1123    pdoc_497_1.pdf         971.0       2003-08-29       1158.0
# ...                ...           ...              ...          ...
# 1214   pdoc_1440_1.pdf         787.0       2006-08-22        801.0
# 1215   pdoc_1047_1.pdf         734.0       2005-10-31          NaN
# 1216     pdoc_55_1.pdf         981.0       2002-06-06        666.0
# 1217     pdoc_50_1.pdf         973.0       2003-05-27        304.0
# 1219   pdoc_1705_1.pdf         824.0       2007-04-10         81.0
#
# [100 rows x 8 columns]

# %% [markdown]
# ### 4.3.1 die Datenspalten zusammenbekommen.

# %%
#hier füge ich sie zusammen
df_dat_zus=df_dat_max.Einreichedatum_x.combine_first(df_dat_max.Einreichedatum_y)

# %%
df_dat_max['Einreichedatum'] = df_dat_zus # hier füge ich die neu enstandene "Series" dem Dataframe an

# %%
df_datum=df_dat_max[["Unnamed: 0_x","VorlageNR_x", "Einreichedatum", "Link Vorstoss-PDF"]]

# %%
df_datum.shape
# Out:
# (1220, 4)

# %%
df_datum["Einreichedatum"].sort_values().tail(30)
# Out:
# 4       2019-09-26
# 3       2019-10-06
# 2       2019-10-07
# 1       2019-10-11
# 0       2019-10-11
# 466            NaN
# 476            NaN
# 487            NaN
# 499            NaN
# 502            NaN
# 511            NaN
# 517            NaN
# 539            NaN
# 543            NaN
# 544            NaN
# 545            NaN
# 561            NaN
# 562            NaN
# 563            NaN
# 576            NaN
# 632            NaN
# 638            NaN
# 749            NaN
# 827            NaN
# 832            NaN
# 842            NaN
# 1006           NaN
# 1154           NaN
# 1194           NaN
# 1207           NaN
# Name: Einreichedatum, dtype: object

# %%
df_datum.to_csv("KRFrames/df_datum_ALLE")

# %% [markdown]
# # 5. Alle Dataframes zusammenfügen
# - Alle einlesen und auf die Unterseiten verweisen
# - eines nach dem andern anhängen
# - noch schön machen und kontrollieren

# %%
# Einlesen:
df_v=pd.read_csv("KRFrames/df_v_Hauptseiten") #Alle Vorstösse mit Infos mit Titel und Nummer der Page mit allen Geschäften
df_dat_all=pd.read_csv("KRFrames/df_datum_ALLE")# Frame mit allen Zeitangaben(Datum)(oben)
df_np=pd.read_csv("KRFrames/Frame_mit_Namen_und_Parteien")# Aus File "02 Namen aus Geschäftsnamen..." Alle Namen und Parteien

# %%
#  zuerst vorputzen
df_v1 = df_v[["VorlageNR", "Geschäft"]].copy()
df_v1
# Out:
#       VorlageNR                                           Geschäft
# 0          3020  Postulat von Luzian Franzini und Esther Haas b...
# 1          3019  Motion von Luzian Franzini, Rita Hofer, Tabea ...
# 2          3018  Interpellation von Fabio Iten, Laura Dittli un...
# 3          3017  Postulat von Tabea Zimmermann Gibson, Stéphani...
# 4          3014  Interpellation der SVP-Fraktion betreffend mob...
# ...         ...                                                ...
# 1215        762  Motion der erweiterten Justizprüfungskommissio...
# 1216        666  Motion der Kommission Teilrevision Personalges...
# 1217        304  Motion von Manuela Weichelt betreffend HIV-Prä...
# 1218        282  Motion von Christoph Hohler betreffend Radstre...
# 1219         81  Motion der vorberatenden Kommission betreffend...
#
# [1220 rows x 2 columns]

# %%
df_dat_all=df_dat_all.rename(columns={"VorlageNR_x": "VorlageNR"})

# %%
df_dat_all
# Out:
#       Unnamed: 0  Unnamed: 0_x  VorlageNR Einreichedatum  \
# 0              0             0       3020     2019-10-11
# 1              1             1       3019     2019-10-11
# 2              2             2       3018     2019-10-07
# 3              3             3       3017     2019-10-06
# 4              4             4       3014     2019-09-26
# ...          ...           ...        ...            ...
# 1215        1215          1215        762     2005-10-31
# 1216        1216          1216        666     2002-06-06
# 1217        1217          1217        304     2003-05-27
# 1218        1218          1218       2635     1995-08-07
# 1219        1219          1219         81     2007-04-10
#
#                                     Link Vorstoss-PDF
# 0                   3020-1-16168_Racial-Profiling.pdf
# 1                  3019-1-16167_Chancengleichheit.pdf
# 2                          3018-1-16166_Praktikum.pdf
# 3        3017-1-16165_Frauenwahl-stimmrecht_Feier.pdf
# 4     3014-1-16159_Geschwindigkeitskontrollen-2-0.pdf
# ...                                               ...
# 1215                                  pdoc_1047_1.pdf
# 1216                                    pdoc_55_1.pdf
# 1217                                    pdoc_50_1.pdf
# 1218                                             1620
# 1219                                  pdoc_1705_1.pdf
#
# [1220 rows x 5 columns]

# %%
# Nun zusammenfügen
df_alles=pd.merge(df_v1, df_dat_all, how="left",on= "VorlageNR")

# %%
df_alles.to_csv("KRFrames/df_alles_ohne_Namen")

# %%
df_np
# Out:
#       Unnamed: 0                Namenganz    P  Unnamed: 0.1  VorlageNR
# 0           1828          Luzian Franzini  ALG             0       3020
# 1           1018              Esther Haas  ALG             1       3020
# 2           1829          Luzian Franzini  ALG             2       3019
# 3           1231               Rita Hofer  ALG             3       3019
# 4           1323  Tabea Zimmermann Gibson  ALG             4       3019
# ...          ...                      ...  ...           ...        ...
# 1895         110         Käty Hofer Buser   SP          1937        836
# 1896          14             Marcel Meyer  CVP          1940        810
# 1897          23              Hans Abicht  FDP          1941        801
# 1898          25         Manuela Weichelt  ALG          1944        304
# 1899          24         Christoph Hohler   SP          1945        282
#
# [1900 rows x 5 columns]

# %%
df_alles_ganz=pd.merge(df_alles, df_np, how="left", on="VorlageNR")
df_alles_ganz
# Out:
#       VorlageNR                                           Geschäft  \
# 0          3020  Postulat von Luzian Franzini und Esther Haas b...
# 1          3020  Postulat von Luzian Franzini und Esther Haas b...
# 2          3019  Motion von Luzian Franzini, Rita Hofer, Tabea ...
# 3          3019  Motion von Luzian Franzini, Rita Hofer, Tabea ...
# 4          3019  Motion von Luzian Franzini, Rita Hofer, Tabea ...
# ...         ...                                                ...
# 1988        762  Motion der erweiterten Justizprüfungskommissio...
# 1989        666  Motion der Kommission Teilrevision Personalges...
# 1990        304  Motion von Manuela Weichelt betreffend HIV-Prä...
# 1991        282  Motion von Christoph Hohler betreffend Radstre...
# 1992         81  Motion der vorberatenden Kommission betreffend...
#
#       Unnamed: 0_x  Unnamed: 0_x Einreichedatum  \
# 0              0.0           0.0     2019-10-11
# 1              0.0           0.0     2019-10-11
# 2              1.0           1.0     2019-10-11
# 3              1.0           1.0     2019-10-11
# 4              1.0           1.0     2019-10-11
# ...            ...           ...            ...
# 1988        1215.0        1215.0     2005-10-31
# 1989        1216.0        1216.0     2002-06-06
# 1990        1217.0        1217.0     2003-05-27
# 1991           NaN           NaN            NaN
# 1992        1219.0        1219.0     2007-04-10
#
#                        Link Vorstoss-PDF  Unnamed: 0_y  \
# 0      3020-1-16168_Racial-Profiling.pdf        1828.0
# 1      3020-1-16168_Racial-Profiling.pdf        1018.0
# 2     3019-1-16167_Chancengleichheit.pdf        1829.0
# 3     3019-1-16167_Chancengleichheit.pdf        1231.0
# 4     3019-1-16167_Chancengleichheit.pdf        1323.0
# ...                                  ...           ...
# 1988                     pdoc_1047_1.pdf           NaN
# 1989                       pdoc_55_1.pdf           NaN
# 1990                       pdoc_50_1.pdf          25.0
# 1991                                 NaN          24.0
# 1992                     pdoc_1705_1.pdf           NaN
#
#                     Namenganz    P  Unnamed: 0.1
# 0             Luzian Franzini  ALG           0.0
# 1                 Esther Haas  ALG           1.0
# 2             Luzian Franzini  ALG           2.0
# 3                  Rita Hofer  ALG           3.0
# 4     Tabea Zimmermann Gibson  ALG           4.0
# ...                       ...  ...           ...
# 1988                      NaN  NaN           NaN
# 1989                      NaN  NaN           NaN
# 1990         Manuela Weichelt  ALG        1944.0
# 1991         Christoph Hohler   SP        1945.0
# 1992                      NaN  NaN           NaN
#
# [1993 rows x 10 columns]

# %%
df_tuti=df_alles_ganz[["VorlageNR","Geschäft", "Namenganz", "P", "Einreichedatum", "Link Vorstoss-PDF"]]

# %%
df_tuti #Wieso wird es nicht ergänzt. Der Fehler ist im File 02 Namen passiert. dort nachschauen.
# Out:
#       VorlageNR                                           Geschäft  \
# 0          3020  Postulat von Luzian Franzini und Esther Haas b...
# 1          3020  Postulat von Luzian Franzini und Esther Haas b...
# 2          3019  Motion von Luzian Franzini, Rita Hofer, Tabea ...
# 3          3019  Motion von Luzian Franzini, Rita Hofer, Tabea ...
# 4          3019  Motion von Luzian Franzini, Rita Hofer, Tabea ...
# ...         ...                                                ...
# 1988        762  Motion der erweiterten Justizprüfungskommissio...
# 1989        666  Motion der Kommission Teilrevision Personalges...
# 1990        304  Motion von Manuela Weichelt betreffend HIV-Prä...
# 1991        282  Motion von Christoph Hohler betreffend Radstre...
# 1992         81  Motion der vorberatenden Kommission betreffend...
#
#                     Namenganz    P Einreichedatum  \
# 0             Luzian Franzini  ALG     2019-10-11
# 1                 Esther Haas  ALG     2019-10-11
# 2             Luzian Franzini  ALG     2019-10-11
# 3                  Rita Hofer  ALG     2019-10-11
# 4     Tabea Zimmermann Gibson  ALG     2019-10-11
# ...                       ...  ...            ...
# 1988                      NaN  NaN     2005-10-31
# 1989                      NaN  NaN     2002-06-06
# 1990         Manuela Weichelt  ALG     2003-05-27
# 1991         Christoph Hohler   SP            NaN
# 1992                      NaN  NaN     2007-04-10
#
#                        Link Vorstoss-PDF
# 0      3020-1-16168_Racial-Profiling.pdf
# 1      3020-1-16168_Racial-Profiling.pdf
# 2     3019-1-16167_Chancengleichheit.pdf
# 3     3019-1-16167_Chancengleichheit.pdf
# 4     3019-1-16167_Chancengleichheit.pdf
# ...                                  ...
# 1988                     pdoc_1047_1.pdf
# 1989                       pdoc_55_1.pdf
# 1990                       pdoc_50_1.pdf
# 1991                                 NaN
# 1992                     pdoc_1705_1.pdf
#
# [1993 rows x 6 columns]

# %%
df_tuti["Einreichedatum"].sort_values().tail(80)
# Obwohl mir nur von 30 Geschäften das Datum fehlt, explodiert dies, wenn es auf die Namen-Tabelle kommt.
# Out:
# 902     NaN
# 906     NaN
# 910     NaN
# 917     NaN
# 920     NaN
#        ...
# 1904    NaN
# 1954    NaN
# 1976    NaN
# 1977    NaN
# 1991    NaN
# Name: Einreichedatum, Length: 80, dtype: object

# %%
df_tuti.to_csv("KRFrames/df_tuti_Ganzes_Frame")

# %% [markdown]
# # Daten aus B&A mit falschen Zahlen
# Eine Lösung wäre, nochmals die Links zu den PDF auslesen und diese in zwei verschiedene Listen verpacken.
# Da die Datenmigration im Jahr 2000 war, schaue ich einfach mal die Zahlen ab 2005 an. Vo dort an, werden die meisten Geschäfte tatsächlich neu sein.
# ## #Andere Variante: ich lasse die B&A einfach weg. Da gibt es eh keine verlässliche Daten. Mengenmässig.
# # Nun plotten

# %%
df_tuti = df_tuti.set_index('Einreichedatum')

# %%
df_tuti
# Out:
#                 VorlageNR                                           Geschäft  \
# Einreichedatum
# 2019-10-11           3020  Postulat von Luzian Franzini und Esther Haas b...
# 2019-10-11           3020  Postulat von Luzian Franzini und Esther Haas b...
# 2019-10-11           3019  Motion von Luzian Franzini, Rita Hofer, Tabea ...
# 2019-10-11           3019  Motion von Luzian Franzini, Rita Hofer, Tabea ...
# 2019-10-11           3019  Motion von Luzian Franzini, Rita Hofer, Tabea ...
# ...                   ...                                                ...
# 2005-10-31            762  Motion der erweiterten Justizprüfungskommissio...
# 2002-06-06            666  Motion der Kommission Teilrevision Personalges...
# 2003-05-27            304  Motion von Manuela Weichelt betreffend HIV-Prä...
# NaN                   282  Motion von Christoph Hohler betreffend Radstre...
# 2007-04-10             81  Motion der vorberatenden Kommission betreffend...
#
#                               Namenganz    P  \
# Einreichedatum
# 2019-10-11              Luzian Franzini  ALG
# 2019-10-11                  Esther Haas  ALG
# 2019-10-11              Luzian Franzini  ALG
# 2019-10-11                   Rita Hofer  ALG
# 2019-10-11      Tabea Zimmermann Gibson  ALG
# ...                                 ...  ...
# 2005-10-31                          NaN  NaN
# 2002-06-06                          NaN  NaN
# 2003-05-27             Manuela Weichelt  ALG
# NaN                    Christoph Hohler   SP
# 2007-04-10                          NaN  NaN
#
#                                  Link Vorstoss-PDF
# Einreichedatum
# 2019-10-11       3020-1-16168_Racial-Profiling.pdf
# 2019-10-11       3020-1-16168_Racial-Profiling.pdf
# 2019-10-11      3019-1-16167_Chancengleichheit.pdf
# 2019-10-11      3019-1-16167_Chancengleichheit.pdf
# 2019-10-11      3019-1-16167_Chancengleichheit.pdf
# ...                                            ...
# 2005-10-31                         pdoc_1047_1.pdf
# 2002-06-06                           pdoc_55_1.pdf
# 2003-05-27                           pdoc_50_1.pdf
# NaN                                            NaN
# 2007-04-10                         pdoc_1705_1.pdf
#
# [1993 rows x 5 columns]

# %%
df_tuti.dtypes
# Out:
# VorlageNR             int64
# Geschäft             object
# Namenganz            object
# P                    object
# Link Vorstoss-PDF    object
# dtype: object
