# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup

# %%
url = "https://kr-geschaefte.zug.ch/gast/geschaefte?commit=Filtern&geschaeft_filter%5Babgeschlossen_bis%5D=&geschaeft_filter%5Babgeschlossen_von%5D=&geschaeft_filter%5Barten_refs%5D%5B%5D=&geschaeft_filter%5Beingereicht_bis%5D=&geschaeft_filter%5Beingereicht_von%5D=&geschaeft_filter%5Bfrist_bis%5D=&geschaeft_filter%5Bhistorische_staende_refs%5D%5B%5D=&geschaeft_filter%5Bkommissionen_refs%5D%5B%5D=&geschaeft_filter%5Bstaende_refs%5D%5B%5D=&geschaeft_filter%5Bstatus_ids%5D%5B%5D=haengig&geschaeft_filter%5Bstatus_ids%5D%5B%5D=abgeschlossen&geschaeft_filter%5Bstatus_ids%5D%5B%5D=&geschaeft_filter%5Btitel%5D=&geschaeft_filter%5Bzustaendig_refs%5D%5B%5D=&page="

alle_seiten = []
for seite in range(1,41):
    r=requests.get(url+str(seite))
    soup = BeautifulSoup(r.text,"html.parser")
    
    tr_list=soup.find_all("tr")[2:] 
    
    for element in tr_list:
        td_list = element.find_all("td")
        href = td_list[0].find("a")["href"]
        text = td_list[1].text
        stand = td_list[2].text
        zustaendig = td_list[3].text
        geschaeft_art = td_list[4].text
        status = td_list[5].text
        
        mini_dict = {"url":href,"Geschäft":text, "Stand":stand, "Zuständigkeit":zustaendig, "Art des Geschäfts": geschaeft_art, "Status":status}

        alle_seiten.append(mini_dict)

# %%
pd.DataFrame(alle_seiten)
# Out:
#                                   Art des Geschäfts  \
# 0                                          Postulat
# 1                                          Postulat
# 2                                            Motion
# 3                                    Interpellation
# 4                                    Interpellation
# 5                                            Wahlen
# 6                                            Motion
# 7                                          Postulat
# 8                                    Interpellation
# 9                                            Wahlen
# 10                                   Interpellation
# 11                                           Motion
# 12    Kantonsratsbeschluss (nicht referendumsfähig)
# 13                                   Kleine Anfrage
# 14                                        Konkordat
# 15                                   Interpellation
# 16                                   Interpellation
# 17                                           Motion
# 18                                         Postulat
# 19    Kantonsratsbeschluss (nicht referendumsfähig)
# 20                                         Postulat
# 21                                   Interpellation
# 22                                         Petition
# 23                                         Petition
# 24                                    Verschiedenes
# 25                                           Gesetz
# 26                                   Kleine Anfrage
# 27                                   Kleine Anfrage
# 28                                   Interpellation
# 29                                           Gesetz
# ...                                             ...
# 1933                                         Motion
# 1934                                         Motion
# 1935                                  Verschiedenes
# 1936                                         Motion
# 1937                                  Verschiedenes
# 1938                                  Verschiedenes
# 1939                                  Verschiedenes
# 1940                                  Verschiedenes
# 1941                                  Verschiedenes
# 1942                                         Motion
# 1943                                  Verschiedenes
# 1944                                  Verschiedenes
# 1945                                  Verschiedenes
# 1946                                  Verschiedenes
# 1947  Kantonsratsbeschluss (nicht referendumsfähig)
# 1948                                  Verschiedenes
# 1949                                  Verschiedenes
# 1950                                  Verschiedenes
# 1951                                  Verschiedenes
# 1952                                  Verschiedenes
# 1953                                  Verschiedenes
# 1954                                  Verschiedenes
# 1955                                  Verschiedenes
# 1956                                  Verschiedenes
# 1954  Genehmigung der Schlussabrechnung betreffend B...
# 1955  Genehmigung der Schlussabrechnung für die Umfa...
# 1956          Genehmigung von acht Schlussabrechnungen:
# 1957  Genehmigung der Schlussabrechnung für das Vorp...
# 1958  Motion von Manuela Weichelt betreffend HIV-Prä...
# 1959  Motion von Christoph Hohler betreffend Radstre...
# 1960  Genehmigung der Schlussabrechnung (K98) betref...
# 1961  Genehmigung der Schlussabrechnung (K40) betref...
# 1962  Motion der vorberatenden Kommission betreffend...
#
#                               Stand         Status  \
# 0      Überweisung an Regierungsrat         hängig
# 1      Überweisung an Regierungsrat         hängig
# 2      Überweisung an Regierungsrat         hängig
# 3      Überweisung an Regierungsrat         hängig
# 4      Überweisung an Regierungsrat         hängig
# 5     Wahl: Feststellung Gültigkeit  abgeschlossen
# 6      Überweisung an Regierungsrat         hängig
# 7      Überweisung an Regierungsrat         hängig
# 8      Überweisung an Regierungsrat         hängig
# 9     Wahl: Feststellung Gültigkeit  abgeschlossen
# 10     Überweisung an Regierungsrat         hängig
# 11     Überweisung an Regierungsrat         hängig
# 12                     Traktandiert         hängig
# 13       Antwort des Regierungsrats  abgeschlossen
# 14              Kommission bestellt         hängig
# 15     Überweisung an Regierungsrat         hängig
# 16     Überweisung an Regierungsrat         hängig
# 17               Erheblicherklärung         hängig
# 18                 Nichtüberweisung  abgeschlossen
# 19              Kommission bestellt         hängig
# 20     Überweisung an Regierungsrat         hängig
# 21     Überweisung an Regierungsrat         hängig
# 22        Überweisung an Kommission         hängig
# 23        Überweisung an Kommission         hängig
# 24                                   abgeschlossen
# 25              Kommission bestellt         hängig
# 26       Antwort des Regierungsrats  abgeschlossen
# 27       Antwort des Regierungsrats  abgeschlossen
# 28     Überweisung an Regierungsrat         hängig
# 29              Kommission bestellt         hängig
# ...                             ...            ...
# 1933                 Datenmigration  abgeschlossen
# 1934                 Datenmigration  abgeschlossen
# 1935                 Datenmigration  abgeschlossen
# 1936                 Datenmigration  abgeschlossen
# 1937                 Datenmigration  abgeschlossen
# 1938                 Datenmigration  abgeschlossen
# 1939                 Datenmigration  abgeschlossen
# 1940                 Datenmigration  abgeschlossen
# 1941                 Datenmigration  abgeschlossen
# 1942                 Datenmigration  abgeschlossen
# 1943                 Datenmigration  abgeschlossen
# 1944                 Datenmigration  abgeschlossen
# 1945                 Datenmigration  abgeschlossen
# 1946                 Datenmigration  abgeschlossen
# 1947                 Datenmigration  abgeschlossen
# 1948                 Datenmigration  abgeschlossen
# 1949                 Datenmigration  abgeschlossen
# 1950                 Datenmigration  abgeschlossen
# 1951                 Datenmigration  abgeschlossen
# 1952                 Datenmigration  abgeschlossen
# 1953                 Datenmigration  abgeschlossen
# 1954                 Datenmigration  abgeschlossen
# 1955                 Datenmigration  abgeschlossen
# 1956                 Datenmigration  abgeschlossen
# 1957                 Datenmigration  abgeschlossen
# 1958                 Datenmigration  abgeschlossen
# 1959                Frist erstreckt         hängig
# 1960                 Datenmigration  abgeschlossen
# 1961                 Datenmigration  abgeschlossen
# 1962                 Datenmigration  abgeschlossen
#
#                          Zuständigkeit                    url
# 0                         Baudirektion  /gast/geschaefte/1998
# 1                         Baudirektion  /gast/geschaefte/1997
# 2                 Gesundheitsdirektion  /gast/geschaefte/1996
# 3                         Baudirektion  /gast/geschaefte/1995
# 4                      Finanzdirektion  /gast/geschaefte/1994
# 5                        Staatskanzlei  /gast/geschaefte/1993
# 6     Direktion für Bildung und Kultur  /gast/geschaefte/1992
# 7                         Baudirektion  /gast/geschaefte/1991
# 8                         Baudirektion  /gast/geschaefte/1990
# 9                        Staatskanzlei  /gast/geschaefte/1989
# 10                        Baudirektion  /gast/geschaefte/1988
# 11    Direktion für Bildung und Kultur  /gast/geschaefte/1987
# 12           Volkswirtschaftsdirektion  /gast/geschaefte/1986
# 13                Direktion des Innern  /gast/geschaefte/1985
# 14                Sicherheitsdirektion  /gast/geschaefte/1984
# 15                        Baudirektion  /gast/geschaefte/1983
# 16                     Finanzdirektion  /gast/geschaefte/1982
# 17                Gesundheitsdirektion  /gast/geschaefte/1981
# 18                     Finanzdirektion  /gast/geschaefte/1979
# 19                        Baudirektion  /gast/geschaefte/1980
# 20                        Baudirektion  /gast/geschaefte/1978
# 21                        Baudirektion  /gast/geschaefte/1977
# 22            Justizprüfungskommission  /gast/geschaefte/1976
# 23            Justizprüfungskommission  /gast/geschaefte/1975
# 24            Justizprüfungskommission  /gast/geschaefte/1974
# 25                Sicherheitsdirektion  /gast/geschaefte/1973
# 26    Direktion für Bildung und Kultur  /gast/geschaefte/1972
# 27                     Finanzdirektion  /gast/geschaefte/1971
# 28                        Baudirektion  /gast/geschaefte/1970
# 29           Volkswirtschaftsdirektion  /gast/geschaefte/1969
# ...                                ...                    ...
# 1933                                    /gast/geschaefte/1335
# 1934                                    /gast/geschaefte/1333
# 1935                                    /gast/geschaefte/1332
# 1936                                    /gast/geschaefte/1331
# 1937                                    /gast/geschaefte/1330
# 1938                                    /gast/geschaefte/1329
# 1939                                    /gast/geschaefte/1328
# 1940                                    /gast/geschaefte/1327
# 1941                                    /gast/geschaefte/1326
# 1942                                    /gast/geschaefte/1325
# 1943                                    /gast/geschaefte/1324
# 1944                                    /gast/geschaefte/1323
# 1945                                    /gast/geschaefte/1322
# 1946                                    /gast/geschaefte/1321
# 1947                                    /gast/geschaefte/1320
# 1948                                    /gast/geschaefte/1319
# 1949                                    /gast/geschaefte/1318
# 1950                                    /gast/geschaefte/1317
# 1951                                    /gast/geschaefte/1316
# 1952                                    /gast/geschaefte/1315
# 1953                                    /gast/geschaefte/1314
# 1954                                    /gast/geschaefte/1313
# 1955                                    /gast/geschaefte/1312
# 1956                                    /gast/geschaefte/1311
# 1957                                    /gast/geschaefte/1310
# 1958                                    /gast/geschaefte/1309
# 1959                      Baudirektion  /gast/geschaefte/1712
# 1960                                    /gast/geschaefte/1308
# 1961                                    /gast/geschaefte/1307
# 1962                                    /gast/geschaefte/1334
#
# [1963 rows x 6 columns]
